# %% [markdown]
# #Trabalho Final de Análise de Visualização de Dados e Projeto Integrado 2
# <b>Relatório do Projeto Sombra</b>
#
#
# ---
# <h2>Análise e Visualização de Dados</h2>
# <h2>Projeto Integrado 2</h2>
# <h3>Mestrado em Humanidades Digitais</h3>
# Ano Letivo 2023/2024
#
# <b>16 de Junho de 2024</b></p>
# <b>Grupo 1 </b>
# *  Francisca Pimenta, PG54508
# *  S. Alexandra Fernandes, PG52766

# %% [markdown]
# ## <b> Índice </b>

# %% [markdown]
# (O Índice encontra-se na aba lateral esquerda)

# %% [markdown]
# ## Sumário Executivo

# %% [markdown]
# <p align="justify">Neste relatório, é possível consultar o trabalho que foi desenvolvido ao longo do semestre nas Unidades Curriculares (UCs) de Análise e Visualização de Dados e Projeto Integrado 2. Assim, construímos e organizámos um arquivo com ficheiros relacionados com os 50 anos da Universidade do Minho, através de recolhas feitas com recurso a <i>web scraping</i>, arquivos e documentos já recolhidos anteriormente e entrevistas realizadas pelos alunos da UC. Estes documentos foram tratados e limpos em contexto de sala de aula, para que pudessem ser analisados através de ferramentas de processamento de linguagem e, posteriormente, os resultados visualizados com a construção de gráficos. Os documentos referidos neste relatório estão em repositórios de <i>Github</i> (um da turma e outro extra para o presente grupo) cujos <i>links</i> podem ser consultados no final deste relatório. Para além do arquivo, utilizámos o primeiro livro da Saga "Harry Potter" para um exercício de Análise de Sentimento. </p>

# %% [markdown]
# ## Introdução

# %% [markdown]
# <p align="justify">Durante o semestre, no âmbito das Unidades Curriculares (UCs) de Análise e Visualização de Dados e Projeto Integrado 2, foi desenvolvido um projeto de análise de um <i>corpus</i> relacionado com o 50.º aniversário da Universidade do Minho.</p>
#
# <p align="justify">Com o título de "Arquivo UM Sombra", este projeto tem por objetivo fazer uma análise e reflexão não só da longa história da Universidade do Minho como instituição, mas também de todas as suas outras facetas (algumas até um pouco escondidas do público em geral) que igualmente fazem parte e contribuem para a sua existência e manutenção: alunos nacionais e internacionais, docentes, funcionários, investigadores, as diferentes áreas científicas, cursos, associações culturais, desportivas, ativismo e voluntariado. </p>
# <p align="justify">Foi ainda realizado um exercício de Análise de Sentimento com o primeiro livro da Saga "Harry Potter". O <i>corpus</i> de sentimentos utilizado neste exercício foi criado e adaptado a partir do documento "SentilexJJ".</p>

# %% [markdown]
# ## Objeto

# %% [markdown]
# <p align="justify">O objeto de estudo deste trabalho final é o <i>corpus</i> do "Arquivo UM Sombra" que foi recolhido, limpo e tratado ao longo do presente semestre.
#
# Este é composto por **896** ficheiros em formato Markdown(.md) divididos por:
#
#
# <ul>
# <li>Artigos recolhidos através de <i> Web Scraping;</i></li>
# <li>Entrevistas recolhidas pelos alunos;</li>
# <li>Entrevistas realizadas no âmbito do Museu da Pessoa.</li>
# </ul>
#
#
# <p align="justify">Ao todo, o <i>corpus</i> é composto por 1192987 palavras, com uma média de 1331 palavras por artigo.</p>
# <p align="justify">Para a criação do corpus foi inicialmente proposto que, para além da recolha das entrevistas e dos artigos através de <i>Web Scraping</i> (um processo de mineração de dados), também fossem realizados inquéritos de forma a obter mais material para o projeto. No entanto, esta ideia não foi incluída no <i>corpus</i> final.
#
# <p align="justify">Para além do processo de construção do corpus, foi necessário o tratamento e limpeza dos dados, construção de metadados e de <i>datasets</i> que estão documentados no Caderno de Campo.</p>
#
# <p align="justify">Adicionalmente, para a análise de sentimento, foi utilizado o primeiro livro da saga "Harry Potter" de J.K. Rowling, "Harry Potter e a Pedra Filosofal" em formato TXT e traduzido para português europeu.</p>

# %% [markdown]
# ### Artigos recolhidos através de <i>Web Scraping</i>

# %% [markdown]
# <p align="justify">Os artigos do nosso <i>corpus</i> são provenientes dos seguintes <i>websites</i>:</p>
#
#
# * <b>ComUm</b> (https://www.comumonline.com/), um jornal <i>online</i> feito por alunos de Ciências da Comunicação da Universidade do Minho com o objetivo de informar o público com notícias da comunidade académica e fornecer apoio aos alunos nos seus percursos académicos.
#   - <b>209 artigos</b>, compostos por 113 048 palavras, datados entre outubro de 2015 e fevereiro de 2024.
#   - Cada artigo possui, em média, <b>541</b> palavras.
# * <b>Jornal Nos</b> (http://www.nos.uminho.pt/), um jornal <i>online</i> da Uminho. Lançado mensalmente e até à presente data conta com 132 edições, não estando todas disponíveis em linha. Contém reportagens, artigos de opinião, a rubrica "Um de Nós", informações sobre formações e ofertas de emprego e uma galeria.
#  - <b>244 artigos</b>, compostos por 272 205 palavras, datados entre junho de 2015 e fevereiro de 2024.
#  - Cada artigo possui, em média, <b>1116</b> palavras.
# * <b>UMDicas</b> (https://www.dicas.sas.uminho.pt/), publicação que disponibiliza informação de teor académico, cultural e desportivo. Uma parte considerável dos artigos estava em formato PDF.
#  - <b>423 artigos</b>, compostos por 685 337 palavras, datados entre outubro de 2004 e novembro de 2023.
#  -  Cada artigo possui, em média, <b>1620</b> palavras.
#
#  <b>Total: 876 artigos em formato Markdown (.md)</b>
#
# <p align="justify">Todos os artigos foram extraídos através de uma técnica de mineração de dados - <i>web scraping</i> - com a excepção de alguns números da publicação "UMDicas" que foram disponibilizados em formato PDF, pelo que o grupo responsável teve que realizar tarefas de conversão e de <i>enconding</i>.</p>

# %% [markdown]
# ### Entrevistas realizadas pelos alunos

# %% [markdown]
# <p align="justify">Para aumentar o <i>corpus</i> do "Arquivo UM Sombra", foi proposto a cada aluno que realizasse uma entrevista, com o entrevistando a seu critério, desde que estivesse relacionado com uma das diversas facetas da Universidade.<p>
#
# Entrevistas dos alunos:
#
# * **Alexandra Fernandes** - Entrevista a Jorge Louro, um dos fundadores da Tuna Universitária do Minho.
# * **Francisca Pimenta** - Entrevista a Catarina Ferreira, estudante do terceiro ano da licenciatura em Marketing na UM.
# * Bárbara Ribeiro - Entrevista a Sara Coutinho, a perspetiva de uma estudante da Universidade do Minho.
# * Cristiana Gomes - Entrevista a Janine Dias, psicóloga.
# * Daniella Cavalheiro - Entrevista a Mário Farelo, professor do departamento de História da Universidade do Minho.
# * Danielle Assis- Entrevista a Deborah Perrota de Andrade, sobre memórias da Universidade do Minho.
# * Diana Pinto - Entrevista a Nelson Martins, estudante de Engenharia Biomédica no seu 5º ano e presidente da EPIC Júnior.
# * Francisca Barros - Entrevista ao Núcleo contra o Assédio (NCA) da Universidade do Minho
# * Gabriela Macieira - Entrevista ao professor Xaquín Núñez-Sabarís.
# * Livia Bettero - Entrevista a Miguel Francisco Almeida Pereira Rocha, professor da Escola de Engenharia Informática.
# * Maurício Barbosa - Entrevista à professora Filomena Louro.
#
# **Total: 11 entrevistas** compostas por 38 625 palavras. Cada entrevista tem, em média, 3511 palavras. Todas em formato Markdown(.md).
#
#
# <p align="justify">A duração da entrevista ficou ao critério de cada um dos estudantes, tendo a maior entrevista (a do aluno Maurício Barbosa) a duração de aproximadamente 1 hora e quarenta minutos.</p>
# <p align="justify">As entrevistas foram realizadas presencialmente ou via <i>Zoom</i> e foram gravadas por telemóvel, câmara ou <i>screen record</i>.</p>
# <p align="justify"><p>Não houve um guião pré-preparado e cada aluno teve a liberdade de preparar as suas perguntas, ou introduzir novas questões, caso sentisse que fosse necessário. No entanto, para garantir o consentimento do/a entrevistado/a, foi sugerido pedir autorização no início da entrevista para o/a filmar/gravar. Para além disso, também foi recomendado pedir previamente aos entrevistados para trazerem um objeto relacionado com as suas memórias da Universidade do Minho ou histórias caricatas/memoráveis relacionadas com a instituição.</p>

# %% [markdown]
# ### Museu da Pessoa

# %% [markdown]
# <p align="justify">Para completar o "Arquivo UM Sombra", foram acrescentadas nove entrevistas realizadas entre os anos de 2000 e 2002, com personalidades relacionadas com a Universidade do Minho, retiradas do Arquivo do Museu da Pessoa, um projeto que tinha como objetivo recolher e reconhecer a importância das histórias pessoais de cidadãos comuns. As entrevistas selecionadas foram as seguintes:</p>
#
# * Alberto Proença
# * Aníbal Alves
# * António Mota
# * Cecília Moreira
# * José Moreira
# * Lúcio Craveiro
# * Manuel Sá
# * Paula Anjo
# * Vasco Freitas
#
# **Total: 9 entrevistas** compostas por 83772 palavras. Cada entrevista tem, em média, 9308 palavras. Todas em formato MarkDown(.md).
#
# <p align="justify">As entrevistas originais foram fornecidas em pastas, identificadas pelos nomes dos entrevistados. Cada pasta possuía quatro documentos no formato XML: "bi.xml" (com dados biográficos e informações relativas ao entrevistado/a), "editado.xml" (a entrevista editada e dividida por temas que foram etiquetados.), "entrevista.xml" (a entrevista com os parágrafos, episódios, perguntas e respostas etiquetadas.) e "entrevistabruto.xml" (a entrevista sem edições e com os parágrafos, perguntas e respostas etiquetados.)</p>
# <p align="justify">Existia ainda uma pasta com o título "TrabalhosAlunos", com uma grelha de análise, conclusões e quadros de categorias.</p>
# <p align="justify">Todos estes documentos estão disponíveis no <i>Github</i> da turma, cujo <i>link</i> encontra-se no final deste relatório.</p>

# %% [markdown]
# ## Objetivos

# %% [markdown]
# <p align="justify">Os objetivos que pretendemos atingir com este projeto são os seguintes:</p>
#
# * Documentar uma parte da história "escondida" da Universidade do Minho através da recolha, realização e análise de artigos e entrevistas.
# * Criação de um <i>corpus</i> significativo que retrate a diversidade e riqueza da comunidade e história da Universidade do Minho.
# * Análise do <i>corpus</i> resultante, através de ferramentas de processamento de linguagem natural.
#   - Extração de nomes de pessoas;
#   - Extração de locais;
#   - Extração de organizações;
#   - Extração de lemas dos verbos;
#   - Extração de datas dos artigos;
#   - Análise de Sentimentos (Harry Potter).
# * Criação de gráficos para a visualização da informação e análise dos mesmos.
# * Realização de uma reflexão final (Conclusão)

# %% [markdown]
# ## Metodologia

# %% [markdown]
# <p align="justify">Para atingir estes objetivos, adotamos diversas metodologias organizadas em várias etapas:</p>
#
#
# #### **Recolha de Dados:**
# <p align="justify">Para a realização deste projeto, a recolha de dados foi um dos passos fundamentais, especialmente no que diz respeito à extração de artigos de páginas de notícias. Para automatizar este processo, utilizámos a linguagem de programação <i>Python</i>, aproveitando as funcionalidades das bibliotecas <i>BeautifulSoup</i> e <i>Scrapy</i>. Estas ferramentas foram ideais para fazer <i>web scraping</i>, permitindo-nos extrair os artigos de páginas <i>web</i> de maneira eficiente e estruturada.</p>
#
# <p align="justify">Para garantir uma divisão equitativa e uma abordagem mais focada e especializada do trabalho, a turma foi dividida por grupos. A divisão dos grupos e das suas respetivas responsabilidades foram organizadas da seguinte forma:</p>
#
# **Grupo 1: Jornal Nós**</p>
# Responsáveis: Andreia, **Francisca** e **Alexandra**</p>
# Tarefas: Este grupo ficou encarregue de recolher artigos do <i>site</i> "Jornal Nós", utilizando as ferramentas de <i>scraping</i> mencionadas anteriormente para extrair os dados relevantes, como títulos, datas, autores e o conteúdo principal dos artigos.</p>
#
# **Grupo 2: ComUm**</p>
# Responsáveis: Gabriela, Maria Francisca e Bárbara</p>
# Tarefas: O segundo grupo ficou responsável pela extração de artigos do site "ComUm". Dedicaram-se a automatizar a recolha de dados deste site, assegurando que todas as informações importantes fossem capturadas e armazenadas corretamente.</p>
#
# **Grupo 3: UMDicas**</p>
# Responsáveis: Cristiana, Diana, Livia e Daniella</p>
# Tarefas: Este grupo de quatro alunas trabalhou com o site "UMDicas". Para além das tarefas de <i>web scraping</i> também tiveram que realizar tarefas de conversão e extração, uma vez que alguns dos artigos só estavam disponíveis em formato PDF.</p>
#
# **Grupo 4: MP Museu da Pessoa**</p>
# Responsáveis: Maurício, Renata  Danielle</p>
# Tarefas: O quarto grupo focou-se no Arquivo do "Museu da Pessoa". Tiveram que realizar tarefas de limpeza e de etiquetação a partir dos ficheiros.
#
#
# <p align="justify">Para além disso, a condução de entrevistas pelos alunos desempenhou um papel significativo na expansão do "Arquivo UM Sombra". Cada aluno foi encarregue de realizar uma entrevista com um indivíduo relacionado com a Universidade do Minho, com liberdade para escolher o entrevistado e o formato da entrevista.</p>
#
#
# #### **Tratamento e Limpeza de Dados**
#
# <p align="justify">Todos os grupos tiveram que realizar tarefas de conversão. Os artigos extraídos estavam em formato HTML e no caso de alguns grupos em XML e PDF. Foi também necessário realizar uma limpeza, através de códigos de linguagem <i>Python</i> para remover informação indesejada.</p>
#
# ##### **Construção de Metadados:**
# <p align="justify">Criámos um cabeçalho de metadados para organizar e categorizar os documentos do <i>corpus</i>.</p>
#
# ##### **Análise e Visualização de Dados**
# <p align="justify">Realizámos tarefas de processamento de linguagem natural para extrair entidades mencionadas, tais como pessoas, organizações e locais, utilizando bibliotecas como o <i>SpaCy</i>. Utilizámos a biblioteca <i>Matplotlib</i> para a visualização dos dados e para facilitar a interpretação dos mesmos. Utilizámos ferramentas como  <i>DataViz</i> para ajudar na nossa escolha de gráficos e programas tais como o <i>Excel</i> para criar gráficos e mostrar as nossas análises estatísticas e o conteúdo dos dados recolhidos.</p>
#
# ##### **Levantamento dos Erros:**
# <p align="justify">Ao longo do processo deste projeto estivemos numa fase contínua de revisão e avaliação dos resultados dos <i>outputs</i>. Assim, realizámos um levantamento dos erros encontrados, qual a sua razão e identificámos os pontos a melhorar. Através de uma análise detalhada e do apoio dos docentes, tentámos sempre ajustar e otimizar os nossos resultados para garantir que os objetivos do projeto fossem atingidos com precisão e eficiência.</p>

# %% [markdown]
# ## Caderno de Campo

# %% [markdown]
# <p align="justify">Este capítulo será dedicado ao Caderno de Campo. Este contém os passos e as operações feitas nos documentos para os obter, limpar e transformar num <i>dataset</i> , para que possa ser possível consultar e relembrar todas as alterações realizadas no <i>corpus</i></p>
# <p align="justify">Tal como foi referido anteriormente, cada grupo ficou encarregue de uma parte do <i>corpus</i>, tendo-nos sido incumbida a tarefa de limpar e adicionar os metadados aos artigos extraídos do <b>Jornal Nós</b>.</p>
# <p align="justify">Neste caderno de campo está igualmente registada a nossa experiência com a entrevista que foi realizada, a experiência realizada em aula de Análise de Sentimento e ainda alguma informação relativa à <i>Makefile</i> e aos ficheiros que a compõem.</p>

# %% [markdown]
# ### Arquivo - Nós

# %% [markdown]
# #### Extração

# %% [markdown]
# ##### Aula

# %% [markdown]
# <p align="justify"><p>A extração inicial dos artigos começou na segunda aula do semestre (09/02/2024), na qual foi abordado o conceito de <i>web scraping</i> e começámos a primeira experiência de extração de artigos do "Jornal Nós".<p>
#
# <blockquote> O web scraping é o processo de recolha de dados estruturados da web de uma forma automatizada. (Cura,2020)
# </blockquote>
#
# <p align="justify"><p>Os dados de um <i>website</i> podem ser salvos através do tradicional "CTRL+C" ou ao salvar a página como um documento. No entanto, também é possível fazê-lo de uma forma automática através de um código <i>Python</i>, por exemplo.</p>
#
# <p align="justify"><p> Assim, de forma a obtermos os primeiros artigos do "Jornal Nós", foi feita uma pesquisa inicial onde verificámos e pesquisámos informações de cariz geral que nos pudessem ajudar com a extração, tal como o número de edições (até à data estavam disponíveis 128 números, atualmente o número já é de 132 publicações), a periodicidade do jornal (trata-se de uma publicação mensal), quais as edições disponíveis (a edição mais antiga disponível era a número 53) e qual o URL onde estão localizados os artigos de cada edição.<p>
#
#
# <p align="justify"><p> Ao clicarmos na edição n.º 128 do jornal verificámos que este número é composto por reportagens, artigos de opinião, artigos sobre investigação e desenvolvimento (I&D), uma secção chamada "UM de nós" (onde é entrevistada uma pessoa ligada à Universidade do Minho) e uma galeria. Verificámos que o URL ligado às publicações tinha a palavra "History" e que foi atribuído o ID 1149 à publicação mais recente .</p>
#
#  *  http://www.nos.uminho.pt/History.aspx?id=1149
#
# <p align="justify"><p> Ao clicar num artigo pudemos igualmente constatar que os artigos possuem a palavra "Article" e um ID associado.
#
# *  http://www.nos.uminho.pt/Article.aspx?id=3692
#
# <p align="justify"><p>Nessa aula fizemos uma experiência com a ferramenta <i>wget</i> na linha de comandos do <i>Windows</i> para realizar a extração em conjunto com a turma. Foi utilizado o código abaixo:

# %%
from jjcli import *


for n in range(1074,1081): # colocar o ID dos artigos aqui. De lembrar que o range não é inclusivo. O valor 1081 equivale ao id=1080
    comando= f'wget -r -c -l 2 "http://www.nos.uminho.pt/History.aspx?id={n}"'
    qxsystem (comando)

# %% [markdown]
# <b>Legenda</b>
#
# * wget: Ferramenta utilizada para fazer o <i>download</i> de ficheiros que usam os protocolos HTTP, HTTPS, FTP e FTPS. (WGET - GNU Project - Free Software Foundation.</i>, s.d.);
# * -r: Faz download de todas as hiperligações e ficheiros no <i>link</i>;
# * -c: O download continua do ponto onde parou;
# * -l 2: O Valor da recursão, neste caso é 2;
# * "http://www.nos.uminho.pt/History.aspx?id={n}": Em "n", o <i>loop</i> substitui os números pelos números colocados na linha acima.

# %% [markdown]
# <p align="justify">No final da aula, ficou decidido que a turma faria em grupo a extração dos artigos do Jornal Nós.</p>

# %% [markdown]
# ##### Extração feita pela turma

# %% [markdown]
# <p align="justify">Pudemos constatar durante a aula que nem todas as edições estão disponíveis no <i>website</i>, sendo a edição mais antiga disponível <i>online</i>, a número 53 de junho de 2015. Esta tem como ID associado o número 1068.</p>
#
# <p align="justify">Uma vez que a turma possui 13 alunos, a extração foi dividida por 12 alunos e o 13.º aluno fez a compilação dos arquivos extraídos para uma pasta do <i>Google Drive</i>. A divisão foi feita da seguinte maneira e o código utilizado para a extração foi o referido anteriormente neste relatório.</p>
#
# * <b>Alexandra</b>: ID 1067-1073
# * <b>Gabriela</b>: ID 1074-1080
# * <b>Bárbara</b>: ID 1081-1087
# * <b>Daniella</b>: ID 1088-1094
# * <b>Francisca B.</b> : ID 1095-1101
# * <b>Renata</b>: ID 1102-1108
# * <b>Lívia </b>: ID 1109-1115
# * <b>Danielle </b>: ID 1116-1122
# * <b>Cristiana </b> ID 1123-1130
# * <b>Diana</b>: ID 1131-1138 Diana
# * <b>Maurício </b>: ID 1139-1145
# * <b>Francisca P.</b>: ID 1146-1149
#
#
# A aluna <b>Andreia Gonçalves</b> ficou encarregue de compilar estes resultados e de os colocar numa pasta do <i>Google Drive</i>. (https://drive.google.com/drive/folders/1wMFEWdMwxv8tgrQ8VXqCBMVi1oaUGiFA)

# %% [markdown]
# #### Inclusão dos Metadados, Tratamento e Preparação dos Ficheiros

# %% [markdown]
# <p align="justify"> Após a extração dos artigos, a próxima atividade foi a de organizar os artigos e extrair os seus metadados para os colocar no cabeçalho. Esta passou por diferentes fases e códigos, uma vez que nos deparámos com alguns obstáculos, os quais tivemos de ultrapassar. </p>

# %% [markdown]
# ##### 1.º Código

# %% [markdown]
# <p align="justify"> Inicialmente fizemos uma experiência de extrair os metadados para um ficheiro YAML.</p>

# %%
from bs4 import BeautifulSoup as bs
from jjcli import *
import yaml
import re

ats = glob("1067-1073/Article.aspx*")  # Função glob para obter uma lista de arquivos que têm nomes a começar por "Article.aspx"
print(ats)

output_data = []

for at in ats:
    with open(at, 'r', encoding="utf-8") as f:
        html = f.read()
        a = bs(html, features="html.parser")

        title = a.find("meta", property="og:title").get("content")
        url = a.find("meta", property="og:url").get("content")
        image = a.find("meta", property="og:image").get("content")
        site_name = a.find("meta", property="og:site_name").get("content")
        description = a.find("meta", property="og:description").get("content")

        # Extrair data e autor
        info_span = a.find("span", id="ctl00_ContentPlaceHolder1_LabelInfo")
        date = ""
        author = ""
        if info_span:
            match = re.search(r'(\d{2}-\d{2}-\d{4}) \| (.+)', info_span.text)
            if match:
                date = match.group(1).strip()
                author = match.group(2).strip()

        # Construir o dicionário de dados para este artigo
        article_data = {
            "-Título": title,
            "URL": url,
            "Site": site_name,
            "Imagem": image,
            "Data": date,
            "Autor": author,
            "Sobre": description

        }

        output_data.append(article_data)

# Escrever os dados em formato YAML
with open("1067-1073.yaml", "w", encoding="utf-8") as file:
    yaml.dump(output_data, file, default_flow_style=False, allow_unicode=True)

# %% [markdown]
# (Excerto do <i>output</i>):
#
#  -Título: Alfredo Guisado levou a Galiza a Pessoa </p>
#   Autor: Nuno Passos</p>
#   Data: 17-06-2015</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150612162734_AlfredoGuisadoapercorrerumaruadeLisboa.jpg</p>
#   Site: Jornal Online UMINHO Alfredo Guisado levou a Galiza a Pessoa</p>
#   Sobre: '</p>
#
#     '
#   URL: http://www.nos.uminho.pt/Article.aspx?id=2136</p>
# -Título: Três décadas de cooperação transfronteiriça</p>
#   Autor: ''</p>
#   Data: ''</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150615005445_CarballoCruz.jpg</p>
#   Site: Jornal Online UMINHO Três décadas de cooperação transfronteiriça</p>
#   Sobre: Não há dúvida que, desde a entrada de Espanha e Portugal na CEE há 30 anos, as relações entre Galiza e Portugal se intensificaram significativamente.</p>
#
#    -Título: Três décadas de cooperação transfronteiriça</p>
#   Autor: ''</p>
#   Data: ''</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150615005445_CarballoCruz.jpg</p>
#   Site: Jornal Online UMINHO Três décadas de cooperação transfronteiriça</p>
#   Sobre: Não há dúvida que, desde a entrada de Espanha e Portugal na CEE há 30 anos, as relações entre Galiza e Portugal se intensificaram significativamente.</p>
#   URL: http://www.nos.uminho.pt/Article.aspx?id=2137</p>
# - -Título: Do Minho a Komano</p>
#   Autor: Catarina Dias</p>
#   Data: 17-06-2015</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150617002035_imagempeq.jpg</p>
#   Site: Jornal Online UMINHO Do Minho a Komano</p>
#   Sobre: ''</p>
#   URL: http://www.nos.uminho.pt/Article.aspx?id=2138</p>
# - -Título: '"A persistência é o caminho do êxito"'</p>
#   Autor: Paula Mesquita</p>
#   Data: 17-06-2015</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150617012051_DPPa129906.jpg</p>
#   Site: Jornal Online UMINHO "A persistência é o caminho do êxito"
#   Sobre: Nasceu e vive em Guimarães há 46 anos, na freguesia de Leitões. Trabalha na UMinho há 28 anos.</p>
#   URL: http://www.nos.uminho.pt/Article.aspx?id=2139</p>
# - -Título: Galegos e portugueses "nunca estiveram tão próximos"</p>
#   Autor: Nuno Passos</p>
#   Data: 17-06-2015</p>
#   Imagem: http://www.nos.uminho.pt/Images/destaques/20150616175626_LogtipodoIDiadaGalizaemBragaemjaneirode2013.jpg</p>
#   Site: Jornal Online UMINHO Galegos e portugueses "nunca estiveram tão próximos"</p>
#   Sobre: ''</p>
#   URL: http://www.nos.uminho.pt/Article.aspx?id=2140</p>

# %% [markdown]
# <p align="justify">Assim, verificámos que era possível extrair os metadados.
# Este código lê os ficheiros HTML e extrai os metadados desejados a partir das tags "meta". No entanto, para extrair a data e o autor foi necessário utilizar uma expressão regular.</p>
#
# <p align="justify"> A data e o autor aparecem da seguinte forma após o título:
#
# * 17-06-2015 | Nuno Passos
#
# Para conseguirmos colocar estes metadados no cabeçalho foi necessário criar 2 grupos de captura. Um primeiro que apanha 2 dígitos, um "-", mais 2 dígitos, outro "-" e por fim 4 dígitos para a data e um segundo que apanha uma sequência de caracteres após "|":</p>
#
# * \d{2}-\d{2}-\d{4}) \| (.+)'
#
# <p align="justify">Depois é construído um dicionário gravado na variável "article_data", onde estão as diferentes TAGS com os seus respetivos valores e, por fim, a lista de dicionários é escrita para um arquivo YAML, neste caso chamado "1067-1073.yaml".</p>
# <p align="justify">Após este código, decidimos verificar se é possível manter o texto dos arquivos e colocar o cabeçalho no topo. Para além disso, decidimos mudar a língua das TAGS para inglês.</p>

# %% [markdown]
# ##### 2.º Código

# %%
from jjcli import *
from bs4 import BeautifulSoup as bs


ats = glob("nos_1067_1073/Article.aspx*")
print(ats)

fo = open ("saida1.txt", 'w', encoding="UTF-8")

def proc_article (html):
    print(len(html))
    a = bs(html)
    cabecalho = ""
    for meta in a.find_all("meta"):
        p = meta.get("property")
        if p is None:
            continue
        p = p.replace("og:", "")
        cabecalho += f"{p}:{meta.get('content')}\n"
        #print(p,":", meta.get("content"))
    art =  a.find("div", id="artigo")
    print("==========\n", cabecalho, art.get_text(), file = fo ) #get_text() invoca a função se não pusermos () ficamos com as tags


for file in ats:
    with open(file, encoding="UTF-8") as f:
        html = f.read()
        proc_article(html)

# %% [markdown]
# (Excerto de um ficheiro do <i>output</i>:)</p>
# ==========</p>
#  title:Alfredo Guisado levou a Galiza a Pessoa</p>
# url:http://www.nos.uminho.pt/Article.aspx?id=2136</p>
# image:http://www.nos.uminho.pt/Images/destaques20150612162734_AlfredoGuisadoapercorrerumaruadeLisboa.jpg</p>
# site_name:Jornal Online UMINHO Alfredo Guisado levou a Galiza a Pessoa</p>
# description:</p>
#
# type:blog</p>
#
#
#
#                             <   voltar à página anterior
#
#
#
#
# Alfredo Guisado levou a Galiza a Pessoa
#
# 17-06-2015 | Nuno Passos
#
#
#
#
#
#
#
#
# Carlos Pazos é professor do (...)

# %% [markdown]
# <p align="justify">Os ficheiros extraídos do Jornal Nós têm os seus metadados nas tags "meta". Este código extrai os metadados  seguintes para o cabeçalho e coloca um separador ("==========") no início do cabeçalho e imprime os resultados num ficheiro TXT chamado "saida1.txt". Os metadados extraídos foram os seguintes:</p>
#
# * Title: O título do artigo.
# * Description: Uma breve descrição do conteúdo do artigo.
# * Image: Um URL da imagem associada ao artigo.
# * URL: O URL do artigo.
# * Type: O tipo do artigo.
#
# <p align="justify">Após a extração destes metadados deparámo-nos com os seguintes problemas:
#
# * Uma vez que decidimos em aula criar e trabalhar com ficheiros da extensão .md, o separador deveria ser "---" antes e depois do cabeçalho de forma a que fosse respeitada a síntese <i>Markdown</i>.
# * Retirar espaços extras que desformatam o ficheiro Markdown.
# * Retirar o "lixo" e números de página. Como por exemplo "<   voltar à página anterior".
# * Colocar a data e o autor no cabeçalho.
# * Colocar "#" antes do título.
# * Mudar o código de "bold" para "**".
# * Em vez de imprimir os textos para o mesmo ficheiro TXT, queremos converter para ficheiros individuais <i>Markdown</i>.</p>

# %% [markdown]
# ##### 3.º Código

# %%
from jjcli import glob
import re
from bs4 import BeautifulSoup as bs


ats = glob("1067-1073/Article.aspx*")
print(ats)

def proc_article(html, output_file):
    # Processa artigo
    a = bs(html, features="html.parser")
    cabecalho = ""
    divisao = "---"

    # Extrair os metadados
    title = a.find("meta", property="og:title").get("content")
    url = a.find("meta", property="og:url").get("content")
    image = a.find("meta", property="og:image").get("content")
    site_name = a.find("meta", property="og:site_name").get("content")
    description = a.find("meta", property="og:description").get("content")

    # Extrair data e autor
    info_span = a.find("span", id="ctl00_ContentPlaceHolder1_LabelInfo")
    date = ""
    author = ""
    if info_span:
        match = re.search(r'(\d{2}-\d{2}-\d{4}) \| (.+)', info_span.text)
        if match:
            date = match.group(1).strip()
            author = match.group(2).strip()

    # Cabeçalho
    cabecalho += f"title: {title}\n"
    cabecalho += f"url: {url}\n"
    cabecalho += f"image: {image}\n"
    cabecalho += f"site name: {site_name}\n"
    cabecalho += f"description: {description}\n"
    cabecalho += f"date: {date}\n"
    cabecalho += f"author: {author}\n"

    art = a.find("div", id="artigo")
    corpo = proc_art_contents(art)

    with open(output_file, "w", encoding="utf-8") as fo:
        print("==========\n", cabecalho, divisao, corpo, file=fo)

def proc_art_contents(art):
    for tag in art.find_all("div", class_="voltar"): tag.extract()
    for tag in art.find_all("div", id="slidesjs-log"): tag.decompose()
    for tag in art.find_all("ul", class_="socialcount"): tag.decompose()
    for tag in art.find_all("div", id="slides"):
        slides = tag.extract()
    for tag in art.find_all("table"):
        tag.insert(0, "\n## TABELA")
    for tag in art.find_all("strong"):
        tag.replace_with("**" + tag.text + "** ")  # sub. **, texto, sub. **
    for tag in art.find_all("div", class_="title"):
        sem_espacos = tag.get_text().strip()
        tag.replace_with("# " + sem_espacos)
    finalt = art.get_text()
    finalt = re.sub(r'\n{3,}', r'\n\n', finalt)
    return finalt

for file in ats:
    with open(file, "r", encoding="utf-8") as f:
        html = f.read()  # lê o ficheiro
        print("A processar:", file)
        art = bs(html, 'html.parser')  # cria objeto BeautifulSoup
        article_id_match = re.search(r'id=(\d+)', file)  # expressões regulares para encontrar o ID
        if article_id_match:
            article_id = article_id_match.group(1)  # extrai o ID
            output_file = f"output_{article_id}.md"  # título do output
            print("Output file:", output_file)  # imprime o output
            proc_article(html, output_file)

# %% [markdown]
# <p align="justify"> Este código Python converte os artigos HTML para formato Markdown.</p>
# <p align="justify">
# Usamos a função glob para encontrar todos os arquivos HTML, neste caso, no diretório 1067-1073 que começam por "Article.aspx". A seguir, estes são armazenados na variável "a" através do <i>Beautiful Soup</i>.</p>
#
# <p align="justify"> Na função "proc_article" os ficheiros HTML são processados e extraídos os seguintes metadados que são adicionados ao cabeçalho dos metadados: </p>
#
# | TAG      | Definição   |
# |----------| ---------|
# | **title** | título do artigo |
# | **url** | url onde se localiza o artigo |
# | **image** |  a imagem utilizada no artigo |
# | **site name** | site de onde foi retirado o artigo
# | **description** |  descrição do artigo |
# | **date**| data da publicação |
# | **author**| autor do artigo|
#
# <p align="justify">
# Na função "proc_art_contents" são removidas tags e elementos HTML que não desejamos manter no texto final através de "tag.extract" e "tag.decompose", formatámos tabelas e modificámos as TAGS do texto a negrito para este ficar entre "**" e tentámos colocar o "#" antes do título do artigo.</p>
#
# <p align="justify">Por fim, o código itera por todos os artigos e altera a sua extensão para ".md". Para além disso, usámos uma expressão regular para extrair o número do ID do artigo e nomear o ficheiro gerado pelo código.</p>

# %% [markdown]
# (Excerto de um ficheiro gerado pelo código)</p>
# ==========</p>
#  title: Alfredo Guisado levou a Galiza a Pessoa</p>
# url: http://www.nos.uminho.pt/Article.aspx?id=2136</p>
# image: http://www.nos.uminho.pt/Images/destaques/20150612162734_AlfredoGuisadoapercorrerumaruadeLisboa.jpg</p>
# site name: Jornal Online UMINHO Alfredo Guisado levou a Galiza a Pessoa</p>
# description: </p>
#
# date: 17-06-2015</p>
# author: Nuno Passos</p>
#  --- </p>
# #
#
# Alfredo Guisado levou a Galiza a Pessoa
#
# 17-06-2015 | Nuno Passos
#
#                         No centenário da revista “Orpheu”, o Centro de Estudos Humanísticos e o Consello de Cultura Galega publicam a tese doutoral de Carlos Pazos sobre o escritor "injustamente esquecido".

# %% [markdown]
# <p align="justify">Apesar de termos conseguido gerar arquivos individuais, ainda se mantiveram alguns problemas, tais como:</p>
#
# * O "#" não está colocado no local correto;
# * Existem ainda muitos espaços no texto que formatam o texto de uma maneira não desejável para o formato Markdown, uma vez que provoca uma indentação;
# * A data e o autor continuam a aparecer após o título;
# * Colocar a TAG "type" (tipo) do ficheiro nos metadados;
# * O cabeçalho ainda não respeita a síntaxe <i>Markdown</i>.
#
# <p align="justify">Para além disso, foi necessário fazer um levantamento dos metadados que estavam a ser utilizados por todos os grupos de forma a que fosse possível uniformizar todos os ficheiros.</p>

# %% [markdown]
# ##### Metadados finais

# %% [markdown]
# <p align="justify"> Os metadados que estavam a ser utilizados por cada grupo foram os seguintes:</p>

# %% [markdown]
# ### **Nos**
#
# | TAG      | Definição   |
# |----------| ---------|
# | **title** | título do artigo |
# | **url** | url onde se localiza o artigo |
# | **image** |  a imagem utilizada no artigo |
# | **site name** | site de onde foi retirado o artigo
# | **type** | tipo de documento, neste caso artigo na maioria |
# | **description** |  descrição do artigo |
# | **date**| data da publicação |
# | **author**| autor do artigo|
#
#
# ### **ComUm**
#
# | TAG      | Definição   |
# |----------| ---------|
# | date| data da publicação |
# | author| autor do artigo|
# | image |  a imagem utilizada no artigo |
# | title | título do artigo |
# | url | url onde se localiza o artigo |
# | **site** | site de onde foi retirado o artigo |
# | description |  descrição do artigo |
# | **tags** | tags associadas ao artigo|
# | type | tipo de documento, neste caso artigo na maioria |
#
# ### **UmDicas**
#
# | TAG      | Definição   |
# |----------| ---------|
# | **Jornal**| local de onde foi retirada a entrevista |
# | **Issue**| número da publicação|
# | **University**|  universidade associada ao ficheiro |
# | **Interviewee(s)** | pessoa a ser entrevistada|
# | Date| data associada à publicação do ficheiro |
# | **Interviewer** | pessoa que conduziu a entrevista |
#
# ### **Museu da Pessoa**
#
# | TAG      | Definição   |
# |----------| ---------|
# | interviewee|  pessoa a ser entrevistada |
# | interviewer | pessoa que conduziu a entrevista |
# | **job**| ocupação da pessoa que foi entrevistada|
# | **place of birth**|  local de nascimento da pessoa entrevistada|
# | **dare of birth** |data de nascimento da pessoa entrevistada|
# | date| data da entrevista |
# | **notes** | notas sobre a entrevista|

# %% [markdown]
# <p align="justify">Na aula de 4 de abril de 2024, foi decidida uma lista final de metadados. Não existia obrigatoriedade de utilizar todas as TAGs, uma vez que os arquivos de cada grupo possuiam necessidades de etiquetação diferentes, sendo esta lista apenas uma proposta.</p>

# %% [markdown]
# #### Proposta de Metadados gerais
#
# | TAG      | Definição   |
# |----------| ---------|
# | <b>date</b>| data da publicação |
# | <b>author</b>| autor do artigo|
# | <b>interviewee</b>|  pessoa a ser entrevistada |
# | <b>interviewer</b> | pessoa que conduziu a entrevista|
# | <b>image</b> |  a imagem utilizada no artigo |
# | <b>title</b> | título do artigo |
# | <b>url</b> | url onde se localiza o artigo (quando não faz sentido, omitir)|
# | <b>site</b> | site de onde foi retirado o artigo ex:UmDicas |
# | <b>description</b> |  descrição do artigo (opcional) |
# | <b>tags</b> | tags associadas ao artigo (_keywords_)|
# | <b>issue</b> | número da publicação (opcional)|
# | <b>type</b> | tipo de documento|

# %% [markdown]
# ##### Código final

# %% [markdown]
# <p align="justify"> Tendo em conta os problemas encontrados anteriormente e a necessidade de organizar os metadados, foi realizado o seguinte código final:</p>

# %%
from jjcli import *
import re
from bs4 import BeautifulSoup as bs


ats = glob("1146-1149/Article.aspx*")  # Função glob para obter uma lista de arquivos que têm nomes que começam com "Article.aspx" no diretório "ext"
print(ats)

titles_dict = {}


def proc_article(html, output_file):
    # Processa um ficheiro Article.aspx@id=\d\d\d\d do jornal NOSuminho
    a = bs(html, features="html.parser")
    cabecalho = ""
    divisao = "---"

    # Extração dos dados do cabeçalho
    title = a.find("meta", property="og:title").get("content")
    url = a.find("meta", property="og:url").get("content")
    image = a.find("meta", property="og:image").get("content")
    site_name = a.find("meta", property="og:site_name").get("content")
    description = a.find("meta", property="og:description").get("content")
    type = a.find("meta", property="og:type").get("content")
    if type == "blog":
        type = "article"

    info_span = a.find("span", id="ctl00_ContentPlaceHolder1_LabelInfo")
    date = ""
    author = ""
    if info_span:
        match = re.search(r'(\d{2}-\d{2}-\d{4}) \| (.+)', info_span.text)
        if match:
            date = match.group(1).strip()
            author = match.group(2).strip()

    # Dicionário com os títulos
    titles_dict[output_file] = title

    # Construir o cabeçalho
    cabecalho += f"date: {date}\n"
    cabecalho += f"author: {author}\n"
    cabecalho += f"image: {image}\n"
    cabecalho += f"title: {title}\n"
    cabecalho += f"url: {url}\n"
    cabecalho += f"site name: {site_name}\n"
    cabecalho += f"description: {description}\n"
    cabecalho += f"type: {type}\n"



    art = a.find("div", id="artigo")
    corpo = proc_art_contents(art)

    if date in corpo and author in corpo:
        corpo = corpo.replace(date, "").replace(author, "")

    conteudo = f"---\n{cabecalho}\n{divisao}\n# {title}\n{corpo}"
    conteudo = conteudo.replace("                        ", "")
    conteudo = conteudo.replace("				", "")
    conteudo = conteudo.replace("|", "")
    conteudo = conteudo.replace("	", "")

    with open(output_file, "w", encoding="utf-8") as fo:
        fo.write(conteudo)


def proc_art_contents(art):
    for tag in art.find_all("div", class_="voltar"):
        tag.extract()
    for tag in art.find_all("div", id="slidesjs-log"):
        tag.decompose()
    for tag in art.find_all("ul", class_="socialcount"):
        tag.decompose()
    for tag in art.find_all("div", id="slides"):
        tag.extract()

    for tag in art.find_all("strong"):

        if tag.parent.name != 'a' and not tag.find_parents('a'):
            tag.replace_with("**" + tag.text + "** ")  # sub. ** , deixa o texto, sub.**

    for tag in art.find_all(["h1", "span"], id="ctl00_ContentPlaceHolder1_LabelTitle"):
        tag.decompose()  # Elimina TAG

    finalt = art.get_text()
    finalt = re.sub(r'\n{3,}', r'\n\n', finalt)

    return finalt


for file in ats:
    with open(file, "r", encoding="utf-8") as f:
        htmlf = f.read()
        art = bs(htmlf, 'html.parser')
        proc_art_contents(art)

for file in ats:
    with open(file, "r", encoding="utf-8") as f:
        htmlf = f.read()  # lê o ficheiro
        print("A processar:", file)
        art = bs(htmlf, 'html.parser')  # cria objeto de BeautifulSoup
        article_id_match = re.search(r'id=(\d+)', file)  # Expressão regular para encontrar o ID
        if article_id_match:
            article_id = article_id_match.group(1)  # Extrai i ID
            output_file = f"output_{article_id}.md"  # Título do ficheiro
            print("Output file:", output_file)  # Imprime o ficheiro
            proc_article(htmlf, output_file)
        else:
            print("O ID não foi encontrado no artigo:", file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b214fb2b13fb> in <cell line: 1>()
# ----> 1 from jjcli import *
#       2 import re
#       3 from bs4 import BeautifulSoup as bs
#       4
#       5
#
# ModuleNotFoundError: No module named 'jjcli'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# <p>(Excerto de um ficheiro que foi gerado pelo código)</p>
#
# ---
# date: 17-06-2015</p>
# author: Nuno Passos</p>
# image: http://www.nos.uminho.pt/Images/destaques/20150612162734_AlfredoGuisadoapercorrerumaruadeLisboa.jpg</p>
# title: Alfredo Guisado levou a Galiza a Pessoa</p>
# url: http://www.nos.uminho.pt/Article.aspx?id=2136</p>
# site name: Jornal Online UMINHO Alfredo Guisado levou a Galiza a Pessoa</p>
# description: </p>
#
# type: article</p>
#
# ---
# # Alfredo Guisado levou a Galiza a Pessoa
#
#
#
#
# No centenário da revista “Orpheu”, o Centro de Estudos Humanísticos e o Consello de Cultura Galega publicam a tese doutoral de Carlos Pazos sobre o escritor "injustamente esquecido".
# (...)

# %% [markdown]
# <p align="justify"> Nesta versão do código tentámos corrigir os problemas com que nos tínhamos deparado no código anterior. </p>
# <p align="justify"> Os espaços em branco foram substituídos através do método "replace" por nada (""), o que resolveu o problema do texto aparecer indentado em locais onde não era desejado.</p>
# <p align="justify"> Adicionamos a TAG "type" nos metadados. No entanto, como no código HTML os artigos estavam classificados como "blog", talvez por pré-definições da página <i>online</i>, fizemos um <i>loop</i> onde sempre que o código encontra a palavra "blog", esta é substituída por "article". Os metadados foram igualmente organizados pela ordem proposta nos metadados finais.</p>
# <p align="justify"> A data e o autor deixaram de aparecer repetidos após o título. Quando o código encontra os grupos de captura, coloca-os no cabeçalho, e se o código encontra o valor de "date" e "author" no corpo, este é substituído por nada.</p>
# <p align="justify"> A nossa maior dificuldade com este código foi na colocação do "#" antes do título. Este aparecia sozinho na linha acima ao título. Tentámos remover espaços em branco, remover paragráfos, quebras de linha e substituir possíveis espaços por nada, no entanto não funcionava. Após muitas tentativas, a solução final foi armazenar o título na TAG "title" e o cardinal numa variável chamada "title_with_hash" que é colocada dentro da variável "conteudo" após "divisao" e antes de "corpo".</p>

# %% [markdown]
# As extrações finais encontram-se na seguinte pasta do <i>Github</i>:
#
# https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/Nos

# %% [markdown]
# ### Entrevista

# %% [markdown]
# <p align="justify"> Nesta secção do caderno de campo referimos as nossas experiências, problemas e conclusões sobre a entrevista que conduzimos.</p>

# %% [markdown]
# #### Alexandra Fernandes

# %% [markdown]
# <p align="justify">Para o exercício da realização de uma entrevista decidi entrevistar Jorge Louro, um dos fundadores da Tuna Universitária do Minho. A minha decisão baseou-se não só no facto de que esta foi a primeira Tuna associada à Universidade do Minho, o que naturalmente a torna "especial", mas também dado que o entrevistando é meu familiar, o que facilitou o nosso contacto.</p>
# <p align="justify">A entrevista foi realizada no dia 2 de abril de 2024 durante o intervalo de almoço do entrevistado, no Convento do Pópulo. Tinha pedido com antecedência para que preparasse algum objeto para mostrar e histórias caricatas para contar durante a entrevista.</p>
# <p align="justify">A entrevista foi gravada com uma câmara e antes de a começar, pedi autorização para a gravação da mesma, a qual foi concedida pelo entrevistando.</p>
# <p align="justify">Tinha levado uma guião, onde tinha planeado algumas perguntas tais como pedir para se apresentar, qual o seu percurso na Universidade do Minho, como é que surgiu a Tuna Universitária, memórias mais marcantes... no entanto, durante o correr da entrevista decidi introduzir novas perguntas, tais como a última sobre qual a música favorita da tuna, ou a pedir mais informações ou clarificações sobre alguma parte da entrevista que achasse que seria interessante para o futuro leitor.</p>
# <p align="justify">Considero que a entrevista foi extremamente fascinante e rica, uma vez que aprendi muito sobre a formação da Tuna Universitária, o festival FITU, viagens, momentos e histórias caricatas que mostram o lado mais humano e pessoal da associação e até mesmo sobre a História da Universidade do Minho, uma vez que a Tuna Universitária nasceu num período de grande dinamismo onde estava a surgir a identidade e imagem da Universidade que toda a comunidade conhece hoje em dia.</p>
# <p align="justify">Uma das minhas maiores dificuldades foi a transcrição da entrevista. Dado que esta teve a duração de aproximadamente 47 minutos, considerei que seria necessário automatizar o processo devido a constrangimentos de tempo, pelo que uma transcrição manual seria inviável para o tempo disponível.</p>
# <p align="justify">Segui a sugestão da colega Gabriela Macieira e utilizei o <i>website TurboScribe</i> para realizar a transcrição automática. Uma vez que o <i>site</i> só aceita transcrever gratuitamente vídeos até 30 minutos, dividi o vídeo da entrevista em diferentes partes. A transcrição tinha alguns erros apesar de estar correta em 75%/80% dos casos. Isto deveu-se à qualidade do som não ter sido a melhor (o entrevistado estava um pouco longe, numa sala com algum eco e num dia de chuva forte.). Os erros mais frequentes que encontrei foram os seguintes:</p>
#
# |TurboScribe    | Correção  |
# |----------| ---------|
# | Turma | Tuna|
# | Toona| Tuna |
# | imigrado |  Leninegrado |
# | árvore | anfiteatro|
# | farto |  fato|
# | Jerês | Gerês|
# | cabaquinho | cavaquinho|
#
# <p align="justify">Talvez devido ao facto de que os ficheiros usados como memórias na aplicação não possuem certos vocábulos, tais como tuna, esta acaba por substituir as palavras por outras semelhantes, ou então devido à qualidade do som (farto/fato; Jerês/Gerês). De salientar que em casos de betacismos, a aplicação também teve alguma dificuldade na grafia da palavra.</p>
# <p align="justify">Após compilar os documentos que obtive da transcrição automática num ficheiro txt, corrigi os erros de transcrição e removi algumas repetições, hesitações, fiz concordâncias que não estavam a ser realizadas na oralidade e corrigi algumas não frases, sempre com o objetivo de me manter fiel à entrevista real e também com a noção de que a naturalidade de um texto oral não se espelha de uma forma confortável para um leitor num texto escrito, sendo necessário realizar alguns acertos.</p>
# <p align="justify">Após o texto txt corrigido, realizei a edição final do texto, onde introduzi alguns títulos para tornar o texto de fácil leitura, coloquei os metadados e etiquetei no diálogo as perguntas, as respostas, e as três partes da entrevista que considerei as mais ricas.</p>
#
# <p align="justify">O PDF criado para oferecer ao entrevistado foi criado através do <i>website</i> "Canva" que permite realizar e editar composições e trabalhos de <i>design</i>.

# %% [markdown]
# Link para a pasta do Github com os ficheiros relacionados com a entrevista: </p>
# https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/EntrevistasAVD/AlexandraFernandes

# %% [markdown]
# #### Francisca Pimenta

# %% [markdown]
# <p align="justify">Esta entrevista está inserida no âmbito do projeto "Arquivo UM Sombra" da disciplina de AVD, que visa explorar a história e as diversas facetas da Universidade do Minho, em comemoração dos seus 50 anos. </p>
# <p align="justify"> Optei por entrevistar a minha amiga Catarina Ferreira, estudante do terceiro ano da licenciatura em Marketing na UM, uma vez que possui um percurso académico de 4 anos repleto de experiências e vivências diversas, tornando-a uma excelente fonte de informação para o projeto.</p>
#
# <p align="justify">A entrevista ocorreu no dia 3 de abril, realizada de forma remota através da plataforma <i>Zoom</i> e teve uma duração total de 18 minutos. Durante esse período, explorei diversos tópicos relacionados com a experiência da Catarina na Universidade, desde as suas motivações iniciais para escolher o curso, até às suas principais aprendizagens e desafios ao longo do seu percurso académico.</p>
#
# <p align="justify">A parte mais interessante o processo foi a entrevista em si. Foi um momento de troca de ideias e experiências muito enriquecedor, onde pude conhecer mais sobre a jornada académica da Catarina e obter informação valiosa para o projeto da disciplina de AVD.</p>
#
# <p align="justify">No entanto, a parte mais desafiadora do processo foi a transcrição da entrevista. Inicialmente, tentei utilizar a ferramenta digital de transcrição de áudio <i>Good Tape</i>, mas os resultados foram desanimadores. A transcrição apresentava inúmeras imprecisões e partes do diálogo estavam incompletas ou mal interpretadas. Diante dessa dificuldade, decidi realizar a transcrição manualmente, o que exigiu mais tempo e esforço da minha parte.</p>
#
# <p align="justify">Para agilizar o processo e garantir uma transcrição mais precisa, recorri outra vez a uma ferramenta digital, desta vez a <i>TurboScribe</i>. Esta ferramenta revelou-se extremamente útil, proporcionando uma transcrição mais fiel do conteúdo original, com poucos erros e uma atenção meticulosa à pontuação e à gramática. Com a ajuda da <i>TurboScribe</i>, consegui concluir a transcrição de forma eficiente e com maior precisão, assegurando assim a qualidade da versão final.</p>
#
# <p align="justify">Apesar dos desafios encontrados na transcrição, o processo de entrevista foi bastante enriquecedor e esclarecedor. Esta experiência fez-me realçar a importância de uma preparação meticulosa e da utilização de ferramentas adequadas para garantir o sucesso de um projeto de pesquisa académica.</p>

# %% [markdown]
# Link para a pasta do Github com os ficheiros relacionados com a entrevista: </p>
# https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/EntrevistasAVD/FranciscaPimenta

# %% [markdown]
# ##### Metadados da entrevista

# %% [markdown]
# <p align="justify">Nas entrevistas também colocamos um cabeçalho com metadados. Tal como no cabeçalho anterior, estes eram uma proposta, pelo que, as TAGS desta lista a serem incluídas na entrevista estavam ao critério de cada aluno.</p>
#
#
# | TAG      | Definição   |
# |----------| ---------|
# | <b>job</b>| ocupação da pessoa que foi entrevistada|
# | <b>place of birth</b>|  local de nascimento da pessoa entrevistada|
# | <b>date of birth</b> |data de nascimento da pessoa entrevistada (circa)|
# | <b>date_interview</b>  | data da entrevista|
# | <b>notes</b> | notas sobre a entrevista|
# | <b>interviewee</b>|  pessoa a ser entrevistada |
# | <b>interviewer</b> | pessoa que conduziu a entrevista|

# %% [markdown]
# ## Análise de sentimento HP

# %% [markdown]
# <p align="justify">Durante o semestre realizámos uma experiência de Análise de sentimento com o livro "Harry Potter e a Pedra Filosofal" através da criação do nosso próprio recurso lexical, criado a partir do documento "SentilexJJ", um recurso fornecido pelo professor José João.</p>
#
# <p align="justify">Na aula fizemos uma pequena experiência com dois pequenos documentos TXT onde estavam algumas palavras/expressões positivas e noutro os equivalentes negativos para verificarmos como funciona o recurso. Após essa primeira experiência, começamos a construir o nosso próprio sentilex.</p>
#
# <p align="justify">Com o código seguinte, e através do ficheiro txt "SentilexJJ", criámos dois ficheiros "positivos.txt" e "negativos.txt". O código lia as linhas dos documentos, e se encontrasse a marcação "POL:N0=-1", adicionava a palavra/expressão (que se encontrasse antes da primeira vírgula) aos sentimentos negativos. Pelo contrário, quando encontrasse "POL:N0=+1", este seria escrito no ficheiro com os sentimentos positivos.</p>

# %%
def negativos(ficheiro):
    with open(ficheiro, 'r') as f:
        with open('negativos.txt', 'a') as file:
            for linha in f:
                if "POL:N0=-1" in linha:
                    word = linha.split(",")[0]

                    file.write(word + '\n')


negativos("sentilexjj.txt")

def positivos(ficheiro):
    with open(ficheiro, 'r') as file:
        with open('positivos.txt', 'a') as file1:
            for linha in file:
                if "POL:N0=1" in linha:
                    word = linha.split(",")[0]

                    file.write(word + '\n')



positivos("sentilexjj.txt")

# %% [markdown]
# <p align="justify">Na aula do dia 12 de abril de 2024 realizámos um exercício de análise de sentimento através do seguinte código:</p>

# %%
import re
import subprocess

def le_livro(nome_livro):
    with open (nome_livro, encoding="utf-8") as arquivo_livro:
        livro=arquivo_livro.read()#Carrega o conteúdo completo do livro para a variável livro
    return livro.split('#')#Quebra o conteúdo o livro por "#", utilizado para sinalizar um novo capítulo

def analisa_capitulos(capitulos):

    dicionario=carrega_lexico()

    for n,capitulo in enumerate(capitulos):
        positivas=0
        negativas=0

        print("-"*50)
        for word in dicionario:
            quantidade=len(re.findall(word,capitulo))
            if dicionario[word]>0:
                positivas+=quantidade
            else:
                negativas+=quantidade
        print(f"Capitulo {n}: Positivas: {positivas} - Negativas: {negativas}")
            #print(f"{word} ({dicionario[word]}): {quantidade}")


def carrega_lexico():
    with open("positivos.txt", encoding="utf-8") as learquivo:
        positivos=learquivo.read().splitlines()
    with open("negativos.txt", encoding="utf-8") as learquivo:
        negativos=learquivo.read().splitlines()

    dicionario_lexico={x:1 for x in positivos} | {x:-1 for x in negativos}#Forma um dicionario lexico com as palavras dos arquivos positivos e negativos

    return(dicionario_lexico)


#capitulos=le_livro("HP.txt")
#print(len(capitulos))
#analisa_capitulos(capitulos)

def anota (m):#devolve a palavra com a anotação, ou então só a palavra caso não esteja no dici
    palavra = m[0] #O 0 é a string inteira que foi apanhada, 1 é o 1º grupo de captura
    if palavra in dicionario:
        return f'[{palavra}]({dicionario[palavra]})'
    else:
       return palavra

def anotaTexto (texto):
    anotado = re.sub(r'\w+',anota, texto) #anota sem () aponta para a função, com () invoca
    print (anotado)
    print(anotado.count("(1)"))
    print(anotado.count("(-1)"))

dicionario=carrega_lexico()
#print(anota("jogo"))
#print(anota("linda"))
anotaTexto (open("capitulo1.txt").read())

# %% [markdown]
# <p align="justify">Este código lê o conteúdo do livro, divide-o em capítulos e, em seguida, analisa cada capítulo para determinar a quantidade de palavras positivas e negativas presentes através dos ficheiros txt criados anteriormente.</p>
#
# <p align="justify">A função le_livro é responsável por ler o conteúdo completo do livro e dividi-lo em capítulos, utilizando um cardinal "#" como delimitador dos capítulos.</p>
#
# <p align="justify">A função analisa_capitulos percorre cada capítulo do livro e utiliza os documentos de palavras positivas e negativas, carregado pela função carrega_lexico para contar o número de ocorrências de cada palavra positiva e negativa. Este imprime a contagem de palavras positivas e negativas por capítulo</p>
#
# <p align="justify">A função carrega_lexico lê as listas de palavras positivas e negativas e cria um dicionário onde as palavras positivas têm o valor 1 e palavras negativas têm o valor -1.</p>
#
# <p align="justify">A função anota é usada para anotar cada palavra no texto com sua polaridade (positiva ou negativa). A função anotaTexto lê o texto do livro, anota cada palavra com a sua polaridade e escreve o texto anotado num novo arquivo chamado HPanotado.txt. Também imprime o texto anotado e o número de ocorrências de palavras positivas e negativas.</p>
#
# <p align="justify">Apesar de sua grande utilidade, o código tem alguns problemas de precisão devido ao facto de que as palavras, apesar de terem conotações positivas, dependendo do contexto podem ter uma conotação negativa (e vice versa), tal como podemos ver nos seguintes exemplos:</p>
#
# * "A professora Mc_Gonagall puxou de um lenço de [renda](-1)..."
#
# <p align="justify">A palavra "renda" pode ter um significado negativo, no entanto, neste caso ao estar inserida num termo multipalavra, o seu significado torna-se neutro.</p>
#
# * "e gritasse [bem]1 alto..."
# * "era [bem]1 provável"
# * "olhar [bem]1 para toda a família."
#
# <p align="justify">Bem, pode ter um significado positivo, porém, neste caso está a funcionar como um quantificador.</p>
#
# <p align="justify">Assim, apesar dos ficheiros serem uma ótima base para este tipo de análise, ainda há muito espaço de manobra para estudar nuances no texto e talvez criar uma lista de termos multipalavra que são "neutros", ou adicionar novos termos positivos e/ou negativos.</p>

# %% [markdown]
# ## Análise dos Dados Obtidos

# %% [markdown]
# <p align="justify">Para fazer a análise do arquivo foi necessário remover o cabeçalho com os metadados para que estes não nos induzissem em erro e aumentassem a frequência de algumas entidades e nomes. Assim, durante a aula, realizámos um código que extrai apenas o <i>corpus</i> para um ficheiro TXT único.</p>
#
# <p align="justify">Utilizámos o código para extrair duas versões do <i>corpus</i>. A primeira com apenas o <i>corpus</i> do Jornal Nós e uma segunda versão do Arquivo UM Sombra com o restante <i>corpus</i> (sem incluír os artigos do Jornal Nós.). Decidimos que essa abordagem tornaria uma comparação dos resultados muito mais rica e elucidativa pois permite-nos verificar possíveis semelhanças - ou diferenças -, identificar padrões e variações em textos do mesmo universo temático.</p>

# %% [markdown]
# ### Código para extrair o Arquivo UM Sombra

# %%
#!/usr/bin/env python3

from jjcli import *
import yaml

# docs = glob("Nos/*.md") + glob("Umdicas/*.md")
docs = glob("MPessoa/*.md") + glob("ComUM/*.md") + glob("UMdicas/*.md") + glob("Entrevistas/*.md") #um glob que apanha uma lista de ficheiros

# print(f"Nos: {len(docs)}")
cl = clfilter("")
cl.args = sorted(docs)

output = open ("corpus-umsombraR.txt",'w', encoding="UTF-8")

for txt in cl.text():
    # print(txt[:100])
    for metadados, body in re.findall(r'---(.*)---(.*)', txt, flags=re.S): #o ponto não apanha new lines, por isso o re.S
        print (f"@{cl.filename()}*\n", body, file=output)

# %% [markdown]
# <p align="justify">Este foi o código utilizado para extrair uma versão do Arquivo UM Sombra sem os artigos do Jornal Nós. Decidimos chamar ao ficheiro de <i>output</i> "corpus-umsombraR.txt" para não surgir qualquer confusão entre um ficheiro com o <i>corpus</i> completo. Deste modo, o "R", representa a inicial da palavra "reduzido". Assim, os documentos que são "apanhados" pela função "glob" são apenas os do Museu da Pessoa, ComUM, UMdicas e as Entrevistas realizadas pelos alunos.</p>

# %% [markdown]
# ### Código para extrair o Jornal Nós

# %%
#!/usr/bin/env python3

from jjcli import *
import yaml

docs = glob("Nos/*.md") #um glob que apanha uma lista de ficheiros

# print(f"Nos: {len(docs)}")
cl = clfilter("")
cl.args = sorted(docs)

output = open ("corpus-nos.txt",'w', encoding="UTF-8")

for txt in cl.text():
    # print(txt[:100])
    for metadados, body in re.findall(r'---(.*)---(.*)', txt, flags=re.S): #o ponto não apanha new lines, por isso o re.S
        print (f"@{cl.filename()}*\n", body, file=output)

# %% [markdown]
# <p align="justify">Foi utilizado um código idêntico para extrair a versão do <i>corpus</i> do Jornal Nós, neste caso a função "glob" apenas seleciona todos os ficheiros de extensão Markdown que existem dentro da pasta "Nos".</p>

# %% [markdown]
# ### Contagem do número de palavras do <i>Corpus</i>

# %% [markdown]
# <p align="justify">De forma a melhor compreendermos a extensão de ambos os <i>corpus</i> que estávamos a analisar, decidímos adaptar um código <i>Python</i> utilizado na aula. Este código imprimia o número total de artigos presentes na pasta, mas decidimos acrescentar ainda o número total de palavras de forma a que conseguíssemos ter uma maior compreensão e noção da extensão dos nossos documentos.</p>
# <p align="justify">O código gerado foi o seguinte:</p>

# %%
#!/usr/bin/env python3

from jjcli import *
import yaml

# Glob apanhar os Arquivos
#docs = glob("ComUM/*.md")
#docs = glob("Nos/*.md")
#docs = glob("UMDICAS/*.md")
#docs = glob("Entrevistas/*.md")
#docs = glob("MPessoa/*.md")
#docs = glob("Nos/*.md") + glob("MPessoa/*.md") + glob("ComUM/*.md") + glob("UMdicas/*.md") + glob("Entrevistas/*.md")
docs = glob("MPessoa/*.md") + glob("ComUM/*.md") + glob("UMdicas/*.md") + glob("Entrevistas/*.md")

# Inicializar o clfilter
cl = clfilter("")
cl.args = sorted(docs)

# Variável para contar o número total de palavras
total_words = 0

# Iterar sobre cada arquivo, ler o conteúdo e contar as palavras
for file_path in docs:
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # Ignorar linhas que começam com #
            if not line.strip().startswith('#'):
                total_words += len(line.split())

# Imprimir o número de documentos e o total de palavras
#print(f"ComUM: {len(docs)}, Total de palavras: {total_words}")
#print(f"UMDicas: {len(docs)}, Total de palavras: {total_words}")
#print(f"Nos: {len(docs)}, Total de palavras: {total_words}")
#print(f"Entrevistas: {len(docs)}, Total de palavras: {total_words}")
#print(f"MPessoa {len(docs)}, Total de palavras: {total_words}")
#print(f"Corpus UM Sombra {len(docs)}, Total de palavras: {total_words}")
print(f"CorpusR: {len(docs)}, Total de palavras: {total_words}")

# %% [markdown]
# <p align="justify">Os <i>outputs</i> obtidos foram os seguintes: </p>
# * CorpusR: 652, Total de palavras: 920782</p>
# * Nos: 244, Total de palavras: 272205</p>
#
# <p align="justify">Assim, o CorpusR possui 652 artigos com aproximadamente 1412 palavras por artigo e o <i>corpus</i> do Jornal Nós 244 artigos com aproximadamente 1115 palavras por artigo em média.</p>
#
# <p align="justify">Neste código tivemos em atenção remover os títulos (no <i>loop</i> sempre que uma linha começa por um cardinal, esta é ignorada), para que pudessemos ter uma noção o mais próxima da realidade da extensão dos documentos.</p>
# <p align="justify">Na secção deste relatório onde é descrito o objeto de estudo, utilizámos este código para a descrição do número de artigos e de palavras totais.</p>

# %% [markdown]
# ### Anotação do <i>Corpus</i>

# %% [markdown]
# <p align="justify"> Após as extrações, ambos os ficheiros txt foram anotados com o código elaborado durante as aulas.</p>
# <p align="justify">Este código importa a biblioteca "spacy" e o módulo "jjcli". A seguir, importámos o modelo "pt_core_news_lg" que foi pré-treinado para processamento de linguagem natural em português. De seguida, é aberto um ficheiro TXT onde vão ser escritos os resultados da análise. No caso do <i>corpus</i> do Jornal Nós foram escritos para o ficheiro "corpus-nos-anotado.txt" e no <i>corpus</i> restante para o ficheiro "corpusR-anotado.txt". Assim, este código escreve no arquivo de saída as palavras, o seu respetivo lema, a classe gramatical e o tipo de entidade para que possamos criar <i>datasets</i> que nos permitam analisar e visualizar a informação presente nos mesmos.</p>

# %%
import spacy
from jjcli import *

# pip install -U spacy
# python -m spacy download en_core_web_sm

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("pt_core_news_lg")

# Process whole documents
#text = ("Viva a Daniella que escreveu um programa Python.")
cl=clfilter("")

# Analyze syntax
#print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
#print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
contador = 0
output = open ("corpus-nos-anotado.txt",'w', encoding="UTF-8")
# Find named entities, phrases and concepts
#for entity in doc.ents:
   # print(entity.text, entity.label_)
for par in cl.paragraph():
    contador += 1
    print(contador)
    doc = nlp(par)
    with doc.retokenize() as retokenizer:
        for entity in doc.ents:
            retokenizer.merge(entity)

    for sentence in doc.sents:
        print(file=output)
        for word in sentence:
            if word.is_space:
                continue
            print(f'{word.text}\t{word.lemma_}\t{word.pos_}\t{word.ent_type_}', file=output) #frequencia dos lemas

# %% [markdown]
#  ### Makefile

# %% [markdown]
# <p align="justify">De forma a automatizar o processo, criámos uma <i>Makefile</i>. Na <i>Makefile</i> escrevemos as regras que ditam como os arquivos relacionados com os códigos devem ser compilados e vinculados para criar os ficheiros finais.</p>
# <p align="justify">Esta foi muito útil para o nosso trabalho pois permitiu-nos atualizar rapidamente e de forma automática o nosso <i>corpus</i> e os <i>datasets</i> conforme fosse necessário.</p>

# %%
titulos.txt:
	python extrai-tit.py

# Extração do corpus
corpus-umsombraR.txt: extrai-body.py
	python extrai-body.py

corpus-nos.txt: extrai-body-nos.py
	python extrai-body.py

# Anotar usando spacy
corpusR-anotado.txt: corpus-umsombraR.txt anotaR.py
	python anotaR.py corpus-umsombraR.txt

# Anotar Nos usando spacy
corpus-nos-anotado.txt: corpus-nos.txt anota-nos.py
	python anota-nos.py corpus-nos.txt

#Calcular Nomes de Pessoa
contaperCORPUSR.csv: corpusR-anotado.txt contaperCORPUSR.py
	python contaperCORPUSR.py corpusR-anotado.txt

contaperNOS.csv: corpus-nos-anotado.txt contaperNOS.py
	python contaperNOS.py corpus-nos-anotado.txt

#Calcular Locais

contalocCORPUSR.csv: corpusR-anotado.txt contalocCORPUSR.py
	python contalocCORPUSR.py corpusR-anotado.txt

contalocNOS.csv: corpus-nos-anotado.txt contalocNOS.py
	python contalocNOS.py corpus-nos-anotado.txt

#Calcular Organizações

contaorgCORPUSR.csv: corpusR-anotado.txt contaorgCORPUSR.py
	python contaorgCORPUSR.py corpusR-anotado.txt

contaorgNOS.csv: corpus-nos-anotado.txt contaorgNOS.py
	python contaorgNOS.py corpus-nos-anotado.txt

# Calc. freq. verbos nosso corpus
verbosCORPUSR.csv: corpusR-anotado.txt contaverbosCORPUSR.py
	python contaverbosCORPUSR.py corpusR-anotado.txt

verbosNOS.csv: corpus-nos-anotado.txt contaverbosNOS.py
	python contaverbosNOS.py corpus-nos-anotado.txt

# Títulos

datasCORPUSR.txt: corpusR-anotado.txt datasCORPUSR.py
	python datasCORPUSR.py corpusR-anotado.txt

datasNOS.txt: corpus-nos-anotado.txt datasNOS.py
	python datasNOS.py corpus-nos-anotado.txt

# Datas

datasNOS.csv: corpus-nos-anotado.txt datasNOSF.py
	python datasNOSF.py corpus-nos-anotado.txt

# %% [markdown]
# ### Extração de Entidades Nomeadas

# %% [markdown]
# <p align="justify">Os primeiros exercícios de extração trataram-se de extrações de Entidades Nomeadas. A fim de manter a clareza e homogeneidade, decidímos associar a cor azul escura ao <i>Corpus</i> Reduzido e a cor azul clara ao Jornal Nós.</p>

# %% [markdown]
# #### Nomes de Pessoa

# %% [markdown]
# <p align="justify">O primeiro exercício que realizámos foi a extração de nomes de pessoas de ambos os <i>datasets</i>. Imprimimos para um ficheiro "csv" todas as entidades classificadas como pessoa "PER" na versão do documento anotado com <i>Spacy</i>. (Realizámos uma versão para o <i>corpus</i> reduzido e outra para o Jornal Nós.)</p>
# <p align="justify">No <i>Excel</i> tivemos que realizar uma correção manual do ficheiro, uma vez que cerca de 3-5 resultados apareciam numa terceira coluna.</p>
# <p align="justify">Para além disso, tivemos que regravar os ficheiros diretamente no <i>Excel</i> com a extensão CSV UTF-8 já que estávamos a ter erros de <i>encoding</i> ao gerar os gráficos.</p>

# %% [markdown]
# ##### Importação dos Nomes de Pessoa - <b>CorpusR</b>

# %%
import pandas as pd


file_path = '/content/contaperCORPUSR.csv'


df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                        PER;Oco
# 0              Ana Marques;151
# 1      Rui Vieira de Castro;96
# 2          Margarida Isaías;92
# 3                      Prof;74
# 4                     ARCUM;71
# 5                      FADU;63
# 6            Nuno Gonçalves;61
# 7              Duarte Lopes;36
# 8                    Muffin;33
# 9              Carlos Silva;31
# 10            António Cunha;28
# 11             Rui Oliveira;28
# 12             Luís Pereira;27
# 13  Marta Rodrigues | ComUM;24
# 14               D. Pedro V;23
# 15           Joana Oliveira;21
# 16            Manuel Heitor;20
# 17                 Afonsina;20
# 18                  Proença;20
# 19          Sónia Fernandes;19
# 20                  Weadapt;19
# 21          António Paisana;17
# 22   Maria Francisca Barros;16
# 23                Nuno Reis;16
# 24           Carlos Videira;16
# 25              Lloyd Braga;16
# 26          Francisco Silva;15
# 27    Elisa Siquara I ComUM;15
# 28             Hélder Matos;14
# ...

# %% [markdown]
# <p align="justify">Fizemos uma importação dos primeiros 30 resultados, apesar de apenas desejarmos os primeiros 15 para os gráficos. Assim, realizámos uma análise dos primeiros resultados para podermos verificar possíveis erros. Encontrámos alguns, pelo que elaborámos uma pequena lista de exclusões para nos gráficos apenas constarem nomes de pessoas.</p>
# <p align="justify"><b>Exclusões:</b> </p>
# * Prof - Neste caso o modelo de análise de linguagem utilizado conseguiu identificar que "Prof." é um título associado a uma pessoa, no entanto, não o conseguiu associar aos nomes com que ocorre, ao contrário da palavra "professor", que aparece associada aos nomes. </p>
# * ARCUM - ARCUM é a sigla da "Associação Recreativa e Cultural Universitária do Minho", logo esta deveria estar associada a Organizações e não pessoas.</p>
# * FADU - FADU é a sigla da "Federação Académica do Desporto Universitário". Também deveria estar incluída na categoria de Organizações.</p>
# * D.Pedro V - Este é o nome de uma pessoa, no entanto, ao verificar manualmente no <i>corpus</i> todas as ocorrências do nome, verificámos que se estava a referir à rua e não à pessoa, pelo que decidimos adicionar o nome à nossa lista de exclusões.</p>
# * Afonsina - Das 20 ocorrências da palavra "Afonsina", 4 estão a referir-se à feira Afonsina em Guimarães e as restantes a uma tuna, à Tuna de Engenharia da Universidade do Minho. Este nome poderia estar associado a Organizações.</p>
# * WeAdapt - A <i>Weadapt</i> trata-se de uma <i>spin off</i> da Universidade do Minho que confeciona roupa confortável e ergonómica para cadeirantes. Assim, o nome encaixa-se nas Organizações e não nos nomes de pessoas.
#
# <p align="justify">Houve casos onde achávamos que um resultado poderia ter sido um "falso-positivo", no entanto, ao verificarmos no ficheiro resultante do <i>corpus</i> reduzido, reparámos que estes se referiam a nomes de pessoas, tal como aconteceu nos casos seguintes:</p>
# * Muffin - Muffin é a alcunha da membro da tuna feminina "Maria Valada". Assim, decidímos no código, substituir ambos os nomes por "Maria Valada ("Muffin"). Curiosamente, apesar do <i>Spacy</i> ter conseguido identificar como pessoa o nome da colega "Marina Mendes", não conseguiu identificar a alcunha da mesma, "Loure", como uma pessoa.</p>
# * Proença - Neste caso "Proença", refere-se ao professor do Centro de Informática que é referido como "Prof. Proença" no <i>corpus</i>. Ainda no mesmo <i>corpus</i> existe mais uma referência a outra pessoa com o apelido "Proença", "Margarida Proença", Professora Catedrática de Engenharia com duas ocorrências: "Margarida Proença" e "Vice-reitora Margarida Proença", pelo que não foi necessário realizar qualquer acerto, mas colocámos a indicação de que se trata da mesma pessoa.</p>
# * Lloyd Braga - O Nome "Lloyd Braga" pode estar associado à pessoa, à Fundação Carlos Lloyd Braga, à Residência Lloyd Braga ou ainda à cátedra Lloyd Braga. Ao contar manualmente no ficheiro do <i>corpus</i> deparámo-nos que apenas 8 das 16 ocorrências se referem à pessoa.</p>
# <p align="justify">
# Também tivemos outros casos tais como:</p>
# * Marta Rodrigues | ComUM - Marta Rodrigues é uma jornalista da ComUM com várias ocorrências no ficheiro. No <i>dataset</i> aparece ainda como "Marta Rodrigues" e "| Marta Rodrigues". No entanto, dado que o nome não aparece referenciado no texto mas sim como possíveis restos de metadados não removidos corretamente, decidimos colocar na lista de excepções.</p>
# * Elisa Siquara I ComUM - Elisa Siquara é outro caso em que o nome de uma jornalista da ComUm tem várias ocorrências. No entanto, tal como no caso anterior decidimos remover esta ocorrência por nos parecer que foram metadados não removidos corretamente.</p>
# * L.G. - L.G. é a sigla com que é referido o estudante "Luís Garcia" que foi entrevistado pela UMDicas, pelo que decidimos associar ao nome "Luís Garcia", uma vez que não entra em conflito com outra possível pessoa com o mesmo nome, pois não encontrámos manualmente no <i>corpus</i> outra ocorrência de outra pessoa com nome igual.</p>

# %% [markdown]
# ###### Visualização dos Nomes de Pessoa - <b>CorpusR</b>

# %% [markdown]
# <p align="justify">Como os Nomes de Pessoas são variáveis categóricas, decidimos utilizar um gráfico de barras, uma vez que nos permite observar com clareza os diferentes nomes de pessoas e o seu número de ocorrências.</p>
# <p align="justify">Decidímos utilizar a mesma cor para todos os nomes para facilitar a leitura do gráfico e não distrair o leitor com cores diferentes que o podem induzir em erro.</p>

# %% [markdown]
# <b>1.ª Tentativa</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contaperCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Nomes que queremos substituir:
data['PER'] = data['PER'].replace({
    "L.G.": "Luís Garcia",
    "Luís Garcia": "Luís Garcia",
    "Muffin": "Maria Valada (\"Muffin\")",
    "Maria Valada": "Maria Valada (\"Muffin\")"
})

# Nomes a excluir
exclude_names = [
    "Prof", "ARCUM", "FADU", "D. Pedro V", "Afonsina", "Weadapt",
    "Elisa Siquara I ComUM", "Elisa Siquara", "Marta Rodrigues | ComUM",
    "| Marta Rodrigues", "Marta Rodrigues"
]
data = data[~data['PER'].isin(exclude_names)]

# Corrigir o número de ocorrências para "LLoyd Braga"
data.loc[data['PER'] == "LLoyd Braga", 'Oco'] = 8

# Agrupar os dados pelo nome e somar as ocorrências
grouped_data = data.groupby('PER')['Oco'].sum().reset_index()

# Ordenar os dados pela contagem de ocorrências
top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Criação do Gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['PER'], grouped_data['Oco'], color='blue')
plt.xlabel('Nome')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Pessoas no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Após analisarmos os resultados desta primeira tentativa, por curiosidade, decidimos verificar o contexto onde aparecem os nomes com maiores ocorrências e voltámos a atualizar a nossa lista de exclusões: </p>
# * Ana Marques - jornalista da UMDicas. Tem 151 ocorrências no <i>Corpus</i>, no entanto, ao verificá-lo manualmente, notámos que este aparece só como referência ao nome da autora do artigo, pelo que decidimos também remover do gráfico final.</p>
# * Nuno Gonçalves - jornalista da UMDicas. Tem 61 ocorrências, mas, dado que ocorre apenas como referência ao autor do artigo, foi adicionado à lista de exclusões.</p>
# * Joana Oliveira - jornalista da ComUM. Tem 21 ocorrências, no entanto como se trata apenas de uma referência ao nome da autora, este foi adicionado à lista de exclusões.

# %% [markdown]
# <b>2.ª Tentativa</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar o dataset
file_path = '/content/contaperCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Substituir os nomes de forma adequada
data['PER'] = data['PER'].replace({
    "L.G.": "Luís Garcia",
    "Luís Garcia": "Luís Garcia",
    "Muffin": "Maria Valada (\"Muffin\")",
    "Maria Valada": "Maria Valada (\"Muffin\")"
})

# Nomes a excluir
exclude_names = [
    "Prof", "ARCUM", "FADU", "D. Pedro V", "Afonsina", "Weadapt",
    "Elisa Siquara I ComUM", "Elisa Siquara", "Marta Rodrigues | ComUM",
    "| Marta Rodrigues", "Marta Rodrigues", "Ana Marques", "Nuno Gonçalves",
    "Joana Oliveira"
]
data = data[~data['PER'].isin(exclude_names)]

# Corrigir o número de ocorrências para "LLoyd Braga"
if 'LLoyd Braga' in data['PER'].values:
    total_lloyd_occurrences = data.loc[data['PER'] == 'LLoyd Braga', 'Oco'].sum()
    data = data[data['PER'] != 'LLoyd Braga']
    data = data.append({'PER': 'LLoyd Braga', 'Oco': 8}, ignore_index=True)

# Agrupar os dados pelo nome e somar as ocorrências
grouped_data = data.groupby('PER')['Oco'].sum().reset_index()

# Ordenar os dados pela contagem de ocorrências e selecionar os primeiros N resultados
top_n = 15  # Defina o número de principais resultados que deseja incluir
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Plotar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['PER'], grouped_data['Oco'], color='blue')
plt.xlabel('Nome')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Pessoas no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">O resultado "Maria Francisca Barros", com 16 ocorrências, ainda se trata da referência ao nome de uma jornalista da ComUM, pelo que foi adicionado à lista de excepções e criámos o gráfico final.</p>

# %% [markdown]
# <b>Gráfico Final</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contaperCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Substituir os nomes
data['PER'] = data['PER'].replace({
    "L.G.": "Luís Garcia",
    "Luís Garcia": "Luís Garcia",
    "Muffin": "Maria Valada (\"Muffin\")",
    "Maria Valada": "Maria Valada (\"Muffin\")"
})

# Nomes a excluir
exclude_names = [
    "Prof", "ARCUM", "FADU", "D. Pedro V", "Afonsina", "Weadapt",
    "Elisa Siquara I ComUM", "Elisa Siquara", "Marta Rodrigues | ComUM",
    "| Marta Rodrigues", "Marta Rodrigues", "Ana Marques", "Nuno Gonçalves",
    "Joana Oliveira", "Maria Francisca Barros", "Lloyd Braga"
]
data = data[~data['PER'].isin(exclude_names)]

# Agrupar os dados pelo nome e somar as ocorrências
grouped_data = data.groupby('PER')['Oco'].sum().reset_index()

# Ordenar os dados pela contagem de ocorrências
top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Criar o gráfico de Barras
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['PER'], grouped_data['Oco'], color='blue')
plt.xlabel('Nome')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Pessoas no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Para este código importámos as bibliotecas pandas (como pd) e a matplotlib.pyplot como plt. De seguida, é carregado o <i>dataset</i> e nos dados da coluna 'PER' substituímos os nomes que desejamos pelo seu novo nome.</p>
# <p align="justify">Abrímos uma lista chamada "exclude_names" que contém todos os nomes da coluna 'PER' que sejam excluídos da coluna final. Na linha a seguir, guardamos na variável "data" uma versão sem os nomes excluídos. O método "isin" verifica se os nomes excluídos estão presentes na coluna 'PER' do <i>dataset</i> e associa "True" se forem encontrados e "False" se não forem encontrados. O operador ~ funciona como uma negação em pandas, e inverte os valores: transforma "True" em "False" e "False" em "True". No final, "data[...]" mantém as linhas que foram etiquetadas como "True" nos dados finais.</p>
#
# <p align="justify">A seguir, agrupa os dados pelo nome e faz a soma dos números em 'Oco'. (Devido à necessidade de termos inicialmente no código substituído alguns nomes para remeterem para a mesma entidade, por isso os seus valores têm que ser somados para obtermos o número real). Depois, decidimos só mostrar os primeiros 15 resultados e ordenámos por ordem de ocorrência.</p>
# <p align="justify">No final, é construído o gráfico.</p>
# <p align="justify">No gráfico observamos duas entidades que possuem um alto destaque: "Rui Vieira Castro", o atual Reitor da Universidade do Minho e "Margarida Isaías", a atual presidente da Associação Académica da Universidade do Minho (AAUM). Ambos possuem quase 100 ocorrências, o que denota a importância de ambos e a sua presença na história da instituição.</p>
# <p align="justify">Os resultados seguintes já possuem uma clara queda, com um número muito menor de ocorrências comparado com as figuras anteriores, (menos de 40 ocorrências), no entanto ainda as coloca numa posição de destaque na história da Instituição, tais como Duarte Lopes, ex-presidente da AAUM. </p>

# %% [markdown]
# <b>Nuvem de Palavras</b>

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt


file_path = '/content/contaperCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Substituir os nomes
data['PER'] = data['PER'].replace({
    "L.G.": "Luís Garcia",
    "Luís Garcia": "Luís Garcia",
    "Muffin": "Maria Valada (\"Muffin\")",
    "Maria Valada": "Maria Valada (\"Muffin\")"
})

# Nomes a excluir
exclude_names = [
    "Prof", "ARCUM", "FADU", "D. Pedro V", "Afonsina", "Weadapt",
    "Elisa Siquara I ComUM", "Elisa Siquara", "Marta Rodrigues | ComUM",
    "| Marta Rodrigues", "Marta Rodrigues", "Ana Marques", "Nuno Gonçalves",
    "Joana Oliveira", "Maria Francisca Barros", "Lloyd Braga"
]
data = data[~data['PER'].isin(exclude_names)]

# Corrigir o número de ocorrências para "LLoyd Braga"
if 'LLoyd Braga' in data['PER'].values:
    total_lloyd_occurrences = data.loc[data['PER'] == 'LLoyd Braga', 'Oco'].sum()
    data = data[data['PER'] != 'LLoyd Braga']
    data = data.append({'PER': 'LLoyd Braga', 'Oco': 8}, ignore_index=True)

# Agrupar os dados pelo nome
grouped_data = data.groupby('PER')['Oco'].sum().reset_index()

# Dicionário com os nomes e suas ocorrências
word_freq = dict(zip(grouped_data['PER'], grouped_data['Oco']))

# Criar a nuvem de palavras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Nuvem de palavras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras dos Nomes em CorpusR')
plt.show()

# %% [markdown]
# <p align="justify">Aproveitámos o código anterior para ainda realizar uma experiência de uma nuvem de palavras. Criámos um dicionário dos nomes e das suas ocorrências que fica guardado na variável "word_freq" e através da biblioteca "Word Cloud" é criada uma nuvem de palavras.</p>
# <p align="justify">Na nuvem de palavras podemos voltar a confirmar que "Rui Vieira de Castro" e "Margarida Isaías" possuem algum destaque, apesar de não ser uma representação desproporcional em relação aos outros nomes que ocorrem no <i>dataset</i>.

# %% [markdown]
# ##### Importação dos Nomes de Pessoa - <b>Jornal Nós</b>

# %% [markdown]
# <p align="justify">A seguir, realizámos o mesmo exercício para o <i>corpus</i> do Jornal Nós.</p>

# %%
import pandas as pd


file_path = '/content/contaperNOS.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                          PER;Oco
# 0                 Lloyd Braga;23
# 1          Carlos Lloyd Braga;16
# 2                       Vítor;12
# 3                       Paula;10
# 4                 Pedro Soares;9
# 5              Carlos Bernardo;8
# 6                 Aníbal Alves;7
# 7             Henedina Antunes;6
# 8          Ana Cláudia Martins;6
# 9                 Xaquín Núñez;5
# 10             Xurxo Fernández;5
# 11                Isabel Silva;5
# 12            Lourenço Marques;5
# 13   Lúcio Craveiro de o Silva;5
# 14                       Lloyd;5
# 15             Chainho Pereira;5
# 16              Joaquim Barros;5
# 17                        Dona;5
# 18                      Orpheu;4
# 19              Ramón Villares;4
# 20                  Pedro Dono;4
# 21              Barbosa Romero;4
# 22                Hernâni Maia;4
# 23  Sérgio Machado de o Santos;4
# 24          Helen Santos Alves;4
# 25                Carlos Pazos;3
# 26             Fernando Pessoa;3
# ...

# %% [markdown]
# <p align="justify">Após a importação dos primeiros 30 resultados, é evidente a diferença de dimensão do <i>corpus</i> do Jornal Nós e do <i>corpus</i> reduzido, dado que o nome com maior ocorrências nesta lista só possui 23 ocorrências, o que é natural, dado que o <i>corpus</i> reduzido possui uma quantidade de artigos superior ao Jornal Nós.</p>
# <p align="justify">Tal como no <i>dataset</i> anterior, começámos a analisar os primeiros 30 resultados para verificar quais os nomes que deveríamos colocar numa lista de exclusões ou combinar no mesmo nome.</p>
# <p align="justify">Lista de exclusões:</p>
# * Dona - Neste caso "Dona", refere-se a um projeto de robótica, pelo que foi incluído na lista de exclusões. Provavelmente o modelo de linguagem utilizado confundiu esta palavra com a forma de tratamento "Dona".</p>
# * Orpheu - No Jornal Nós, todas as ocorrências da palavra "Orpheu" referem-se à publicação, pelo que passou a integrar a nossa lista de exclusões.</p>
# <p align="justify">Lista de combinações:</p>
# * "Carlos Lloyd Braga", "Lloyd Braga" e "Lloyd" - Estes são os nomes com o maior número de ocorrências, no entanto, tivemos que fazer uma análise manual para verificar se se tratavam da pessoa, da residência, da fundação ou da Cátedra. Assim, das 16 ocorrências de "Carlos Lloyd Braga", uma está relacionada com a residência e as restantes com a pessoa. No caso de "Lloyd Braga", 22 ocorrências referem-se à pessoa, enquanto que a restante à residência. Nas 5 ocorrências de "Lloyd", apenas 4 se referem à pessoa, enquanto que uma refere-se à residência. Dado que os nomes se referem à mesma pessoa, tivemos que os colocar na lista de nomes a serem substituídos.</p>
# * "Carlos Pazos" e "Carlos Pazos Justo" - Estas duas entidades referem-se à mesma pessoa, pelo que foi necessário fazer essa associação.</p>
# * "Veiga Simão" e "José Veiga Simão" - São a mesma entidade pelo que decidímos associar uma à outra.</p>
# <p align="justify">Outros casos:</p>
# * Vítor - O nome "Vítor" aparece no <i>corpus</i> 12 vezes. De forma a percebermos de quem se tratava, verificámos manualmente o <i>corpus</i> do Jornal Nós. Conseguímos verificar que Vítor refere-se a "Vítor Rodrigues" que aparece na entrevista de 30 de abril de 2016. No entanto, ao analisar o <i>corpus</i> do Jornal Nós anotado, verificámos que ainda "Vítor de Carapeços" refere-se a "Vítor Rodrigues" e "Vítor**" também. Para além disso, uma ocorrência de "Vítor", referente ao Vítor Rodrigues foi etiquetada como "organização" e existe ainda outro caso onde "Vítor" não foi etiquetado. Assim, existem duas ocorrências de Vítor que não estão a ser contadas e é necessário adicionar ao resultado final. Para além deste caso, durante a análise manual também reparámos que aconteceu num caso "Manuel Vítor" não ter sido etiquetado como pessoa, apenas cada um dos nomes como nome próprio, pelo que existem 3 ocorrências e não apenas 2.</p>
# * Paula - O nome "Paula" também ocorre 10 vezes no Jornal Nós e após uma análise manual, verificámos que se trata de "Paula Costa" referida no mesmo artigo. Porém, ao consultar o ficheiro anotado, verificámos algumas falhas de contagem. Em 4 casos, a mesma Paula foi etiquetada apenas como "nome próprio" sem ter sido associado que se tratava de uma pessoa e num caso foi etiquetada como uma localidade. </p>
# * Lúcio Craveiro da Silva - Dado que existe uma biblioteca baptizada com o nome do antigo reitor, decidimos verificar no <i>corpus</i> anotado e pudemos confirmar que os resultados referem-se à pessoa. </p>

# %% [markdown]
# ###### Visualização dos Nomes de Pessoa - <b>Jornal Nós</b>

# %% [markdown]
# <b>Gráfico Final</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contaperNOS.csv'
data = pd.read_csv(file_path, sep=';')

# Subs. Nomes
replace_names = {
    "Lloyd Braga": "Carlos Lloyd Braga",
    "Lloyd": "Carlos Lloyd Braga",
    "Carlos Pazos": "Carlos Pazos Justo",
    "Veiga Simão": "José Veiga Simão",
    "Vítor": "Vítor Rodrigues",
    "Vítor de Carapeços": "Vítor Rodrigues",
    "Vítor**": "Vítor Rodrigues",
    "Paula": "Paula Costa"
}

exclude_names = ["Orpheu", "Dona"]


data['PER'] = data['PER'].replace(replace_names)
data = data[~data['PER'].isin(exclude_names)]

# Ajuste de ocorrências
data.loc[data['PER'] == "Carlos Lloyd Braga", 'Oco'] = 22
data.loc[data['PER'] == "Lloyd Braga", 'Oco'] = 22
data.loc[data['PER'] == "Lloyd", 'Oco'] = 4
data.loc[data['PER'] == "Vítor Rodrigues", 'Oco'] += 2
data.loc[data['PER'] == "Paula Costa", 'Oco'] += 5

# Soma
grouped_data = data.groupby('PER')['Oco'].sum().reset_index()


top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Gráfico
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['PER'], grouped_data['Oco'], color='skyblue')
plt.xlabel('Nome')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Pessoas no Jornal Nós')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Aproveitámos o código anterior para realizar o gráfico relativo ao Jornal Nós.</p>
# <p align="justify">Ao contrário do gráfico anterior, o nome que mais se destaca é o de "Carlos Lloyd Braga", antigo reitor, professor e ministro da educação, com cerca de 60 ocorrências, enquanto que a segunda entidade, "Paula Costa" já só tem quase um terço de ocorrências. "Vítor Rodrigues" que também é referido no mesmo artigo que "Paula Costa" possui um número semelhante. Os restantes resultados ocorrem menos do que 10 vezes.  </p>

# %% [markdown]
# <b> Nuvem de Palavras </b>

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

file_path = '/content/contaperNOS.csv'
data = pd.read_csv(file_path, sep=';')

# Substituir os nomes
replace_names = {
    "Lloyd Braga": "Carlos Lloyd Braga",
    "Lloyd": "Carlos Lloyd Braga",
    "Carlos Pazos": "Carlos Pazos Justo",
    "Veiga Simão": "José Veiga Simão",
    "Vítor": "Vítor Rodrigues",
    "Vítor de Carapeços": "Vítor Rodrigues",
    "Vítor**": "Vítor Rodrigues",
    "Paula": "Paula Costa"
}

exclude_names = ["Orpheu", "Dona"]

data['PER'] = data['PER'].replace(replace_names)
data = data[~data['PER'].isin(exclude_names)]

# Ajuste de ocorrências
data.loc[data['PER'] == "Carlos Lloyd Braga", 'Oco'] = 22
data.loc[data['PER'] == "Lloyd Braga", 'Oco'] = 22
data.loc[data['PER'] == "Lloyd", 'Oco'] = 4
data.loc[data['PER'] == "Vítor Rodrigues", 'Oco'] += 2
data.loc[data['PER'] == "Paula Costa", 'Oco'] += 5


grouped_data = data.groupby('PER')['Oco'].sum().reset_index()

# Dicionário com os nomes e suas ocorrências
word_freq = dict(zip(grouped_data['PER'], grouped_data['Oco']))

# Criar a nuvem de palavras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Nuvem de palavras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras dos Nomes no Jornal Nós')
plt.show()

# %% [markdown]
# <p align="justify">Na nuvem de palavras observamos a tendência anterior, onde "Carlos Lloyd Braga" é o nome que domina a nível de ocorrências no <i>dataset</i>, apesar de que não é uma representação desproporcional.</p>

# %% [markdown]
# ##### Comparação dos Nomes de Pessoas - <b>Jornal Nós e CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Jornal Nós
file_path_nos = '/content/contaperNOS.csv'
data_nos = pd.read_csv(file_path_nos, sep=';')

replace_names_nos = {
    "Lloyd Braga": "Carlos Lloyd Braga",
    "Lloyd": "Carlos Lloyd Braga",
    "Carlos Pazos": "Carlos Pazos Justo",
    "Veiga Simão": "José Veiga Simão",
    "Vítor": "Vítor Rodrigues",
    "Vítor de Carapeços": "Vítor Rodrigues",
    "Vítor**": "Vítor Rodrigues",
    "Paula": "Paula Costa"
}

exclude_names_nos = ["Orpheu", "Dona"]

data_nos['PER'] = data_nos['PER'].replace(replace_names_nos)
data_nos = data_nos[~data_nos['PER'].isin(exclude_names_nos)]

data_nos.loc[data_nos['PER'] == "Carlos Lloyd Braga", 'Oco'] = 22
data_nos.loc[data_nos['PER'] == "Lloyd Braga", 'Oco'] = 22
data_nos.loc[data_nos['PER'] == "Lloyd", 'Oco'] = 4
data_nos.loc[data_nos['PER'] == "Vítor Rodrigues", 'Oco'] += 2
data_nos.loc[data_nos['PER'] == "Paula Costa", 'Oco'] += 5

grouped_data_nos = data_nos.groupby('PER')['Oco'].sum().reset_index()

top_n = 15
grouped_data_nos = grouped_data_nos.sort_values(by='Oco', ascending=False).head(top_n)

# CorpusR
file_path_corpusr = '/content/contaperCORPUSR.csv'
data_corpusr = pd.read_csv(file_path_corpusr, sep=';')

replace_names_corpusr = {
    "L.G.": "Luís Garcia",
    "Luís Garcia": "Luís Garcia",
    "Muffin": "Maria Valada (\"Muffin\")",
    "Maria Valada": "Maria Valada (\"Muffin\")"
}

exclude_names_corpusr = [
    "Prof", "ARCUM", "FADU", "D. Pedro V", "Afonsina", "Weadapt",
    "Elisa Siquara I ComUM", "Elisa Siquara", "Marta Rodrigues | ComUM",
    "| Marta Rodrigues", "Marta Rodrigues", "Ana Marques", "Nuno Gonçalves",
    "Joana Oliveira", "Maria Francisca Barros", "Lloyd Braga"
]

data_corpusr['PER'] = data_corpusr['PER'].replace(replace_names_corpusr)
data_corpusr = data_corpusr[~data_corpusr['PER'].isin(exclude_names_corpusr)]

grouped_data_corpusr = data_corpusr.groupby('PER')['Oco'].sum().reset_index()

grouped_data_corpusr = grouped_data_corpusr.sort_values(by='Oco', ascending=False).head(top_n)

# Coloca os gráficos à beira um do outro
fig, axs = plt.subplots(1, 2, figsize=(20, 8))

# Gráfico (Jornal Nós)
axs[0].bar(grouped_data_nos['PER'], grouped_data_nos['Oco'], color='skyblue')
axs[0].set_xlabel('Nome')
axs[0].set_ylabel('Número de Ocorrências')
axs[0].set_title(f'Top {top_n} Ocorrências de Pessoas no Jornal Nós')
axs[0].set_xticklabels(grouped_data_nos['PER'], rotation=90)

# Plot Gráfico (CorpusR)
axs[1].bar(grouped_data_corpusr['PER'], grouped_data_corpusr['Oco'], color='blue')
axs[1].set_xlabel('Nome')
axs[1].set_ylabel('Número de Ocorrências')
axs[1].set_title(f'Top {top_n} Ocorrências de Pessoas no CorpusR')
axs[1].set_xticklabels(grouped_data_corpusr['PER'], rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-fa8fdd67b435>:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(grouped_data_nos['PER'], rotation=90)
# <ipython-input-3-fa8fdd67b435>:75: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(grouped_data_corpusr['PER'], rotation=90)

# %% [markdown]
# <p align="justify">Aproveitámos os códigos anteriores e através do <i>ChatGPT</i> encontrámos a funcionalidade* "subplot" do Matplotlib que permite colocar os gráficos à beira um do  outro, para que os possamos comparar.</p>
# <p align="justify">Em ambos os gráficos existe uma queda acentuada a nível de ocorrências após o primeiro e segunda entidades respetivamente. Curiosamente, "Carlos Lloyd Braga" não está no TOP 15 do <i>CorpusR</i> e "Rui Vieira de Castro" e "Margarida Isaías" também não aparecem nos primeiros 15 resultados, o que denota que provavelmente as áreas de interesses do Jornal Nós e o restante <i>Corpus</i> UM Sombra são diferentes.
# <p align="justify">Deve-se ainda notar que no gráfico da direita, no total, existem mais ocorrências do que no gráfico da esquerda devido ao diferente volume de dados nos dois <i>corpus</i>.</p>

# %% [markdown]
# #### Nomes de Locais

# %% [markdown]
# <p align="justify">O segundo exercício que realizámos foi a extração de locais de ambos <i>datasets</i>. Imprimimos para um ficheiro "csv" todas as entidades classificadas como localidade "LOC" na versão do documento anotado com <i>Spacy</i>.</P>
# <p align="justify">Com estes ficheiros tivemos de mais uma vez realizar uma correção manual no <i>Excel</i> de alguns resultados que ficaram colocados em colunas diferentes.</p>
# <p align="justify">Para além disso, tivemos que regravar os ficheiros com a extensão CSV UTF-8 para resolver problemas de <i>encoding</i>.</p>

# %% [markdown]
# ##### Importação dos locais - <b>CorpusR</b>

# %% [markdown]
# <p align="justify">Começámos por importar os primeiros resultados para fazer uma análise do <i>dataset</i>.</p>

# %%
import pandas as pd


file_path = '/content/contalocCORPUSR.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                          LOC;Oco
# 0   Universidade de o Minho;1132
# 1                      Braga;553
# 2                  Guimarães;374
# 3                em Portugal;339
# 4                   Portugal;300
# 5                     UMinho;299
# 6               Universidade;244
# 7                   AAUMinho;184
# 8                    Gualtar;163
# 9                      Porto;129
# 10             Universidades;125
# 11                    Lisboa;119
# 12                    Azurém;118
# 13                    Europa;108
# 14                Moçambique;108
# 15               universidade;99
# 16                       FADU;94
# 17                      SASUM;93
# 18                      Minho;88
# 19                    Bolonha;87
# 20                    Governo;86
# 21                    Coimbra;79
# 22                     Escola;73
# 23            Ensino Superior;68
# 24                   Desporto;67
# 25                        RGA;64
# 26                    Espanha;64
# ...

# %% [markdown]
# <p align="justify">Após a importação dos primeiros 30 resultados, começamos por analisar os resultados obtidos para criar a nossa lista de exclusões, combinações, falsos positivos e outros casos. De notar que os resultados obtidos tratam-se dos lemas das palavras, sendo por isso que alguns resultados tais como "Universidade do Minho" aparecem como "Universidade de o Minho".</p>
# <p align="justify">Lista de combinações:</p>
# * "Universidade de o Minho" e "Uminho" - Ambos os termos são relativos à mesma instituição, pelo que houve a necessidade de os combinar.</p>
# * "Portugal" e "em Portugal" - Os termos referem-se ao mesmo país. </p>
# <p align="justify">Decidimos utilizar como critério de exclusão, quando o termo não é relativo a um local, quando o local não é claro, ou após uma análise do <i>corpus</i> extraído e anotado nos parecer que a referência é maioritariamente à instituição/organização e não ao local físico.</p>
# * "Universidade" e "universidade" - Dado que as palavras podem estar a referirem-se a  diferentes Universidades e não apenas à Universidade do Minho, decidimos colocar na lista de exclusões.</p>
# * "AAUMinho" - Apenas em alguns raros casos que "AAUMinho" foi etiquetado como "LOC" se referem à sede da Associação. Assim, decidimos colocar na lista de exclusões, uma vez que considerámos que houve muitos falsos positivos e que na maior parte dos casos, esta deveria ter sido etiquetada como "ORG" (organização).</p>
# * "Universidades" - Dado que a palavra "Universidades" engloba várias instituições de ensino sem referir quais são as mesmas, decidimos colocar na lista de exclusões, de forma a termos resultados mais definidos e que possamos dizer com certeza de que se tratam.</p>
# * "FADU" - FADU é a sigla da Federação Académica de Desporto Universitário. Após uma consulta do <i>corpus</i>, considerámos que quando "FADU" é referido no <i>corpu</i>, este é relativo à "organização" e não à sede, pelo que decidimos colocar na lista de exclusões.</p>
# * "SASUM" - SASUM é relativo aos Serviços de Ação Social Universidade do Minho. No entanto, após uma consulta do <i>corpus</i> anotado, concluímos que se trata de uma referência aos serviços como "organização" e não do local em específico, pelo que decidimos também remover este resultado do gráfico final.</p>
# * "Governo" - Após uma análise do <i>corpus</i> anotado, dado que "Governo" se refere ao "Governo" como uma instituição e não como um "local", decidimos adicionar a palavra às nossas exclusões.</p>
# * "Escola" e "Ensino Superior" - Ao longo do <i>corpus</i> "Escola" e "Ensino Superior" são utilizados como uma referência ao ensino e não às instalações de um local em específico. </p>
# * "Desporto" - A palavra "Desporto" refere-se a uma atividade física e não a um local.</p>
# * "RGA" - "RGA" refere-se à Reunião Geral de Alunos e não sendo um local físico.</p>

# %% [markdown]
# ###### Visualização dos Locais - <b>CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = '/content/contalocCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Substituir
data['LOC'] = data['LOC'].replace({
    "Universidade de o Minho": "Universidade do Minho",
    "UMinho": "Universidade do Minho",
    "em Portugal": "Portugal"
})

# Lista de exclusão
exclude_names = [
    "Universidade", "universidade", "AAUMinho", "Universidades", "FADU", "SASUM",
    "Governo", "Escola", "Ensino Superior", "Desporto", "RGA"
]

# Excluir
data = data[~data['LOC'].isin(exclude_names)]

# Agrupar os dados
grouped_data = data.groupby('LOC')['Oco'].sum().reset_index()


top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Gráfico
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['LOC'], grouped_data['Oco'], color='blue')
plt.xlabel('Local')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Locais no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Aproveitámos o código utilizado anteriormente. Sempre que nos deparámos com 'PER' substituímos por 'LOC', colocámos as novas exclusões e as novas subtituíções de palavras. Para manter a clareza, decidimos também substituir "Universidade de o Minho" para "Universidade do Minho."</p>
# <p align="justify">Dado que o tema do <i>corpus</i> é a Universidade do Minho considerámos natural esta ser a ocorrência com o maior destaque e número de resultados (um pouco mais de 1400 ocorrências). As localidades seguintes estão diretamente relacionadas com a localização física da Universidade: Portugal, Braga, Guimarães e Gualtar. (Porém, Azurém ficou um pouco distanciado a nível do número de ocorrências). As localidades "Europa", "Bolonha" e "Minho" também remetem diretamente para o universo da Universidade do Minho. Apesar  de em número menor, ocorrências como "Porto", "Valença", "Moçambique" e "Espanha" demonstram a conexão e a colaboração que a Universidade realiza com diferentes países e cidades.</p>

# %% [markdown]
# ##### Importação dos locais - <b>Jornal Nós</b>

# %%
import pandas as pd


file_path = '/content/contalocNOS.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                        LOC;Oco
# 0                  Portugal;54
# 1                     Braga;40
# 2               em Portugal;39
# 3                    Galiza;37
# 4                 Guimarães;33
# 5   Universidade de o Minho;30
# 6                    UMinho;30
# 7                    Lisboa;24
# 8                    Azurém;24
# 9                       EUA;23
# 10                   Angola;18
# 11                   Brasil;17
# 12                   Europa;15
# 13                  Gualtar;12
# 14                 Reitoria;11
# 15                    Minho;10
# 16                     AFUM;10
# 17              Reino Unido;10
# 18                   Espanha;9
# 19           Largo de o Paço;8
# 20                Moçambique;8
# 21              Universidade;8
# 22                    Escola;8
# 23                Via Láctea;7
# 24                    França;7
# 25                     Porto;6
# 26                     Norte;6
# 27                    Itália;6
# 28                    África;6
# ...

# %% [markdown]
# <p align="justify">Após a importação dos primeiros 30 resultados,  tal como na extração de nomes, notámos a diferença da dimensão de ambos os <i>datasets</i>, sendo este de dimensões claramentes menores. Assim, prontamente começámos a nossa análise com os critérios utilizados na visualização anterior.</p>
# <p align="justify">Lista de combinações:</p>
# * "Portugal" e "em Portugal" - Referem-se ao mesmo local, pelo que decidimos combinar os termos.</p>
# * "Universidade de o Minho" e "UMinho" - Tal como no caso anterior, trata-se do mesmo local.</p>
# * "Norte" - Verificámos que "Norte" se está a referir a "Norte de Portugal" (que também ocorre no <i>corpus</i>).
# <p align="justify">Outros casos:</p>
# * "Reitoria" - Inicialmente considerámos que "Reitoria" poderia ter sido um falso negativo, no entanto, após uma análise do <i>corpus</i> concluímos que realmente se trata de uma referência ao edifício da Reitoria, excepto em 2 casos, onde se trata de uma referência à Reitoria como organização.</p>
# <p align="justify">Exclusões:</p>
# * "AFUM" - AFUM é a sigla da Associação de Funcionários da Universidade do Minho. No <i>corpus</i> anotado esta refere-se à associação e não a um local, pelo que esta associação deveria ter sido etiquetada como "ORG".</p>
# * "NIG" - É a sigla do Núcleo de Informática de Guimarães. Dado que verificando o contexto em que aparece no <i>corpus</i> do Jornal Nós, decidimos remover este resultado.</p>
# * "Via láctea" - "Via láctea" no contexto do Jornal Nós está a referir-se ao projeto da rede "Via Láctea" que engloba as Universidades do Minho, Santiago de Compostela, Kanazawa e Aichi Prefectural, sendo uma organização e não um local.</p>
# * "Escola" - No Jornal Nós as referências a "Escola" parecem remeter a duas escolas diferentes da Universidade do Minho, a Escola de Psicologia e a Escola de Economia e Gestão. No entanto, dado que o contexto é o da escola como instituição e não como local físico, colocámos na lista de exclusões.</p>
# * "Universidade" - "Universidade" no <i>corpus</i> do Jornal Nós refere-se não só à Universidade do Minho (como instituição e não como local), mas também a "Universidade" como o grau de ensino, pelo que decidimos colocar na lista de exclusões.</p>

# %% [markdown]
# ###### Visualização dos Locais - <b>Jornal Nós</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contalocNOS.csv'
data = pd.read_csv(file_path, sep=';')

# Substituição
replace_names = {
    "em Portugal": "Portugal",
    "Universidade de o Minho": "Universidade do Minho",
    "UMinho": "Universidade do Minho",
    "Norte": "Norte de Portugal"
}

exclude_names = ["AFUM", "NIG", "Via láctea", "Escola", "Universidade"]

data['LOC'] = data['LOC'].replace(replace_names)
data = data[~data['LOC'].isin(exclude_names)]

# Reitoria
data.loc[(data['LOC'] == "Reitoria"), 'Oco'] = 9

# Soma das ocorrências dos nomes iguais
grouped_data = data.groupby('LOC')['Oco'].sum().reset_index()

top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Criação do Gráfico
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['LOC'], grouped_data['Oco'], color='skyblue')
plt.xlabel('Local')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Locais no Jornal Nós')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">O código utilizado foi adaptado do código utilizado para a visualização dos dados de nomes do Jornal Nós, com a adição da linha "data.loc[(data['LOC'] == "Reitoria"), 'Oco'] = 9" que atualiza o número de ocorrências de Reitoria no <i>dataset</i> de 11 para 9. </p>
# <p align="justify">No Jornal Nós "Portugal" ocorre o maior número de vezes (cerca de 90 vezes), seguido de "Universidade do Minho" (cerca de 60), "Braga" (40), "Galiza" e "Guimarães". Neste gráfico conseguimos inferir que no Jornal Nós é dado um maior impacto à relevância não apenas nacional da Universidade do Minho, mas também internacional através da ocorrência de locais como "Galiza","EUA", "Angola", Brasil", "Europa", "Reino Unido" e "Espanha".   </p>

# %% [markdown]
# ##### Comparação dos Locais - <b>Jornal Nós e CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Jornal Nós
file_path_nos = '/content/contalocNOS.csv'
data_nos = pd.read_csv(file_path_nos, sep=';')

replace_names_nos = {
    "em Portugal": "Portugal",
    "Universidade de o Minho": "Universidade do Minho",
    "UMinho": "Universidade do Minho",
    "Norte": "Norte de Portugal"
}

exclude_names_nos = ["AFUM", "NIG", "Via láctea", "Escola", "Universidade"]

data_nos['LOC'] = data_nos['LOC'].replace(replace_names_nos)
data_nos = data_nos[~data_nos['LOC'].isin(exclude_names_nos)]

data_nos.loc[(data_nos['LOC'] == "Reitoria"), 'Oco'] = 9

grouped_data_nos = data_nos.groupby('LOC')['Oco'].sum().reset_index()

top_n = 15
grouped_data_nos = grouped_data_nos.sort_values(by='Oco', ascending=False).head(top_n)

# CorpusR
file_path_corpusr = '/content/contalocCORPUSR.csv'
data_corpusr = pd.read_csv(file_path_corpusr, sep=';')

replace_names_corpusr = {
    "Universidade de o Minho": "Universidade do Minho",
    "UMinho": "Universidade do Minho",
    "em Portugal": "Portugal"
}

exclude_names_corpusr = [
    "Universidade", "universidade", "AAUMinho", "Universidades", "FADU", "SASUM",
    "Governo", "Escola", "Ensino Superior", "Desporto", "RGA"
]

data_corpusr['LOC'] = data_corpusr['LOC'].replace(replace_names_corpusr)
data_corpusr = data_corpusr[~data_corpusr['LOC'].isin(exclude_names_corpusr)]

grouped_data_corpusr = data_corpusr.groupby('LOC')['Oco'].sum().reset_index()

grouped_data_corpusr = grouped_data_corpusr.sort_values(by='Oco', ascending=False).head(top_n)

# Criação dos Gráficos ao lado um do outro
fig, axs = plt.subplots(1, 2, figsize=(20, 8))

# Gráfico Nós
axs[0].bar(grouped_data_nos['LOC'], grouped_data_nos['Oco'], color='skyblue')
axs[0].set_xlabel('Local')
axs[0].set_ylabel('Número de Ocorrências')
axs[0].set_title(f'Top {top_n} Ocorrências de Locais no Jornal Nós')
axs[0].set_xticklabels(grouped_data_nos['LOC'], rotation=90)

# Gráfico CorpusR
axs[1].bar(grouped_data_corpusr['LOC'], grouped_data_corpusr['Oco'], color='blue')
axs[1].set_xlabel('Local')
axs[1].set_ylabel('Número de Ocorrências')
axs[1].set_title(f'Top {top_n} Ocorrências de Locais no CorpusR')
axs[1].set_xticklabels(grouped_data_corpusr['LOC'], rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-e6452db70df6>:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(grouped_data_nos['LOC'], rotation=90)
# <ipython-input-14-e6452db70df6>:64: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(grouped_data_corpusr['LOC'], rotation=90)

# %% [markdown]
# <p align="justify">Através do código gerado anteriormente, aproveitámos o mesmo para colocar os gráficos lado a lado para os podermos comparar.</p>
# <p align="justify">No primeiro gráfico, "Portugal" ocorre mais vezes e "Universidade do Minho" em segundo lugar, enquanto que no segundo esses resultados estão invertidos.</p>
# <p align="justify">Apesar de terem um número de ocorrências diferente, existem localidades que são referidas em ambos os gráficos tais como "Braga", "Guimarães", "Azurém" e "Gualtar", o que é natural, dado que são os locais físicos da instituição. No entanto, os locais relacionados diretamente com a Universidade do Minho aparecem mais frequentemente, enquanto que no Jornal Nós são referidos países diferentes, o que nos leva a inferir que no Jornal Nós há um foco especial para a presença internacional da UMinho e enquanto que também existe no segundo gráfico, neste os resultados são mais focados na presença nacional.</p>

# %% [markdown]
# #### Nomes de Organizações

# %% [markdown]
# <p align="justify">O terceiro exercício que realizámos foi a extração de organizações dos dois <i>datasets</i>. Todas as entidades classificadas como organização "ORG" foram escritas para um ficheiro CSV.</p>
# <p align="justify">Dado que algumas das organizações contêm vírgulas, estávamos a ter problemas a importar os dados. Assim, tivemos que utilizar o seguinte código e utilizar o sinal de igual "=" como um separador.</i></p>

# %%
import csv

#input = 'contaorgNOS.csv'
#output = 'contaorgNOSV.csv'

input = 'contaorgCORPUSR.csv'
output = 'contaorgCORPUSRV.csv'

virgula = ','
separador = '='

# Ler o CSV
with open(input, mode='r', newline='', encoding='utf-8') as infile:
    reader = csv.reader(infile, delimiter=virgula)
    rows = list(reader)

# Cria novo CSV
with open(output, mode='w', newline='', encoding='utf-8') as outfile:
    writer = csv.writer(outfile, delimiter=separador)
    writer.writerows(rows)

print(f"Ficheiro convertido -> {output}")

# %% [markdown]
# ##### Importação das Organizações - <b>CorpusR</b>

# %% [markdown]
# <p align="justify"> Começámos por importar os dados.</p>

# %%
import pandas as pd


file_path = '/content/contaorgCORPUSRV.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                                               ORG;Oco
# 0                                            AAUM;578
# 1                                           ComUM;176
# 2                                        Academia;167
# 3                            Associação Académica;141
# 4                                  Conselho Geral;125
# 5   Associação Académica de o Universidade de o Mi...
# 6                                              CFJ;72
# 7                           Departamento Alimentar;64
# 8                                     Departamento;63
# 9                                               CG;57
# 10                                            Tuna;57
# 11                                    Licenciatura;52
# 12                                         UMinho?;51
# 13                                         serviço;48
# 14                                             DAF;48
# 15                                             TUM;46
# ...

# %% [markdown]
# <p align="justify">Após a importação, começámos a analisar os primeiros 30 resultados e a sinalizar casos para as listas de exclusão, de substituição/combinação e de outros casos.</p>
#
# <p align="justify">Lista de combinações:</p>
# * "FCT" - Sigla da "Fundação para a Ciência e a Tecnologia". No <i>dataset</i> existe ainda a ocorrência de "Fundação para Ciência e Tecnologia".</p>
# * "Universidade?" e "Academia?" - Ambas palavras ocorrem num final de perguntas, tendo ficado com o ponto de interrogação associado. Esta palavra ocorre em perguntas que são feitas aos entrevistandos dos artigos em relação às suas memórias da Universidade do Minho, pelo que decidimos associar também a "Universidade de o Minho" e "Uminho-". Associámos igualmente "Academia" e "Academia Minhota" a esta entidade.</p>
# * "EUSA" - Sigla da "European University Sports Associety." Para além da sigla "EUSA" também ocorre "European University Sports Association" no <i>dataset.</i>.</p>
# * "GSI" - Sigla do Gabinete de Sistemas de Informação. No <i>dataset</i> também ocorre com "Gabinete de Sistemas de Informação", "Gabinete de Sistemas de Informação de o Universidade de o Minho" e "Gabinete de Sistemas de Informação de o UMinho".</p>
# * "SAS" - Sigla dos "Serviços de Acção Social". No <i>dataset</i> ocorre também como "Serviços de Ação Social", "Serviços de Acção Social", "Serviços de Acção Social?", "Serviços de Acção Social de o UM",  "Serviços de Ação Social de o Academia Minhota" "Serviços de Ação Social de o Universidade de o Minho" e "Serviços de Acção Social de o Universidade de o Minho". </p>
# * "Bomboémia" - Também ocorre como "Bomboémia?" </p>
# * "Conselho Cultural" - No <i>dataset</i> é referido como "Conselho Cultural de o Universidade de o Minho", "Conselho Cultural de o UMinho", "Conselho Cultural?" e "conselho Cultural".</p>
# * "RUM" - Ocorre também como "Rádio Universitária" e "Rádio Universitária de o Minho".</p>
# * "TUM" - Também presente no <i>dataset</i> como "Tuna Universitária de o Minho".</p>
# * "DAF" - Sigla do Departamento Administrativo e Financeiro dos SASUM. Ocorre também como "Departamento Administrativo e Financeiro" e "Departamento Administrativo e financeiro de o SASUM".</p>
# * "CG" e "Conselho Geral" - São a mesma organização, pelo que decidimos combinar as mesmas. Também ocorre em "Conselho Geral de o Universidade", "conselho geral", "Conselho Geral de o UM", "Conselho Geral?" e "o Conselho Geral".</p>
# * "Departamento Alimentar" - Também ocorre como "Departamento Alimentar de o Serviços de Acção Social de o Universidade de o Minho", "departamento Alimentar" e "Departamento Alimentar de o Serviços de Acção Social de o UMinho".</p>
# * "CFJ" - Sigla de Conselho Fiscal e Judicial. Também aparece como "Conselho Fiscal e Jurisdicional de o AAUMinho" e "Conselho Fiscal e Jurisdicional".</p>
# * "AAUM" e "Associação Académica da Universidade do Minho" - Ambas são a mesma organização. Também ocorre como " "Associação Académica de o Universidade de o Minho"" "Associação académica de o Universidade de o Minho", "associação Académica", "Associação Académica" "associação académica de o Universidade de o Minho", "Associação Académica?", "associação académica de o UMinho" e "Associação Académica de o UMinho".</p>
# <p align="justify">Exclusões:</p>
# * "serviço" - Ao consultar o <i>corpus</i> decidimos que esta palavra foi um falso positivo pelo que foi excluída.
# * "Licenciatura" - Licenciatura é relativa a um curso, pelo que não é uma organição, pelo que decidimos excluir do gráfico final.</p>
# <p align="justify">Devido a constrangimentos de tempo, decidimos ainda excluir os resultados:</p>
# * "Tuna" e "Departamento"</p>
# <p align="justify">Numa futura análise seria interessante reler o <i>corpus</i> e fazer as ligações de que "Tuna" e "Departamento" estas palavras se referem.</p>

# %% [markdown]
# ###### Visualização das Organizações - <b>CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contaorgCORPUSRV.csv'
data = pd.read_csv(file_path, sep=';')

# Substituição
replace_names = {
    "Fundação para Ciência e Tecnologia": "FCT",
    "Universidade?": "UMinho",
    "Academia?": "UMinho",
    "Universidade de o Minho": "UMinho",
    "Uminho-": "UMinho",
    "Academia": "UMinho",
    "Academia Minhota": "UMinho",
    "European University Sports Associety": "EUSA",
    "Gabinete de Sistemas de Informação": "GSI",
    "Gabinete de Sistemas de Informação de o Universidade de o Minho": "GSI",
    "Gabinete de Sistemas de Informação de o UMinho": "GSI",
    "Serviços de Ação Social": "SASUM",
    "SAS": "SASUM",
    "Serviços de Acção Social": "SASUM",
    "Serviços de Acção Social?": "SASUM",
    "Serviços de Acção Social de o UM": "SASUM",
    "Serviços de Ação Social de o Academia Minhota": "SASUM",
    "Serviços de Ação Social de o Universidade de o Minho": "SASUM",
    "Serviços de Acção Social de o Universidade de o Minho": "SASUM",
    "Bomboémia?": "Bomboémia",
    "Conselho Cultural de o Universidade de o Minho": "Conselho Cultural",
    "Conselho Cultural de o UMinho": "Conselho Cultural",
    "Conselho Cultural?": "Conselho Cultural",
    "conselho Cultural": "Conselho Cultural",
    "Rádio Universitária": "RUM",
    "Rádio Universitária de o Minho": "RUM",
    "Tuna Universitária de o Minho": "TUM",
    "Departamento Administrativo e Financeiro": "DAF",
    "Departamento Administrativo e financeiro de o SASUM": "DAF",
    "Conselho Geral": "CG",
    "Conselho Geral de o Universidade": "CG",
    "conselho geral": "CG",
    "Conselho Geral de o UM": "CG",
    "Conselho Geral?": "CG",
    "o Conselho Geral": "CG",
    "Departamento Alimentar de o Serviços de Acção Social de o Universidade de o Minho": "Departamento Alimentar",
    "departamento Alimentar": "Departamento Alimentar",
    "Departamento Alimentar de o Serviços de Acção Social de o UMinho": "Departamento Alimentar",
    "Conselho Fiscal e Jurisdicional de o AAUMinho": "CFJ",
    "Conselho Fiscal e Jurisdicional": "CFJ",
    "Associação Académica da Universidade do Minho": "AAUM",
    "Associação académica de o Universidade de o Minho": "AAUM",
    "Associação Académica de o Universidade de o Minho": "AAUM",
    "associação Académica": "AAUM",
    "associação académica de o Universidade de o Minho": "AAUM",
    "Associação Académica?": "AAUM",
    "Associação Académica": "AAUM",
    "associação académica de o UMinho": "AAUM",
    "Associação Académica de o UMinho": "AAUM",
    "UMinho?" : "UMinho"
}

exclude_names = [
    "serviço",
    "Licenciatura",
    "Tuna",
    "Departamento"
]

data['ORG'] = data['ORG'].replace(replace_names)
data = data[~data['ORG'].isin(exclude_names)]

# Soma das ocorrências dos nomes iguais
grouped_data = data.groupby('ORG')['Oco'].sum().reset_index()

top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Criação do Gráfico
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['ORG'], grouped_data['Oco'], color='darkblue')
plt.xlabel('Organização')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Organizações no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Com os códigos anteriores como base realizámos o presente gráfico.</p>
# <p align="justify">"AAUM" é a organização que mais se destaca no <i>dataset</i> com mais de 800 ocorrências. Em segundo lugar está "UMinho" com um número muito menor, apesar de consideravelmente elevado quando comparado com as restantes ocorrências (um pouco mais de 300 ocorrências.)
# "CG", "ComUM" e "SASUM" encontram-se na casa das centenas e as restantes organizações ocorrem num número menor que 100 vezes. Não obstante, este gráfico revela que existe uma grande variedade de temáticas de organizações relacionadas com a Universidade do Minho, desde organizações admnistrativas e de serviços académicos tais como o "CG" (Conselho Geral) e o SASUM, organizações culturais como os "Bomboémia" e a "RUM" e organizações focadas em investigação, como o "GSI".</p>

# %% [markdown]
# ##### Importação das Organizações - <b>Jornal Nós</b>

# %%
import pandas as pd


file_path = '/content/contaorgNOSV.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#                          ORG;Oco
# 0                         CVR;11
# 1                       Google;9
# 2                      UMinho?;7
# 3                         ePsi;7
# 4                          ICS;7
# 5                          USC;6
# 6         Escola de Engenharia;6
# 7                    Accenture;6
# 8                          FCT;6
# 9                     Reitoria;5
# 10                         IEP;5
# 11                        FCLB;5
# 12                        ISET;5
# 13   Ciências de o Comunicação;5
# 14                        EPsi;5
# 15                        ILCH;4
# 16          Escola de Ciências;4
# 17                         CEG;4
# 18              União Europeia;4
# 19        Escola de Psicologia;4
# 20  Instituto Superior Técnico;4
# 21       Universidade Católica;4
# 22                       CEHUM;3
# 23     Serviços de Ação Social;3
# 24                      CCDR-N;3
# 25     Relações Internacionais;3
# 26                         GPI;3
# ...

# %% [markdown]
# <p align="justify">Após a importação dos dados, começámos a fazer a limpeza dos primeiros dados e a criar as listas de exclusão, substituição e outros casos relevantes.</p>
# <p align="justify">Lista de exclusões:</p>
# * "25 de abril" -  Dado que 25 de abril no <i>corpus</i> do Jornal Nós se refere uma data, foi colocado na lista de exclusões.</p>
# * "Ciências de o Comunicação" - Neste caso, refere-se à disciplina e não a uma organização.</p>
# * "Relações Internacionais" - No contexto do Jornal Nós, "Relações Internacionais", refere-se à área de estudo e não a uma organização.</p>
# <p align="justify">Lista de substituições:</p>
# * "Accenture" - Existe um ocorrência de "**Accenture**" no <i>corpus</i>, pelo que foi necessário associar as duas ocorrências.</p>
# * "FCT" - Existem ainda no <i>corpus</i> uma ocorrência de "Fundação para a Ciência e Tecnologia" e "Fundação para a Ciência"</p>
# * "ILCH" - Associámos "ILCH" a "Instituto de Letras e Ciências Humanas" que também ocorre no <i>dataset</i>.</p>
# * "ePsi" e "EPsi" - Estas siglas referem-se à Escola de Psicologia da UMinho. No entanto, existem ainda outras ocorrências da mesma entidade no <i>Corpus</i>, tais como: "Escola de Psicologia", "Escola de Psicologia de o UMinho", "Escola de psicologia". </p>
# * "CEG" - No <i>dataset</i> ocorre como "Centro de Estudos Galegos".</p>
# * "UMinho?" - Verificámos o <i>corpus</i> e chegámos à conclusão que a palavra "UMinho" ocorria em perguntas, tendo o "Spacy" associado o ponto de interrogação à palavra. Assim decidimos retirar o ponto de interrogação e associar este resultado a "UMinho*" que também ocorre no <i>corpus</i>.</p>

# %% [markdown]
# ###### Visualização das Organizações - <b>Jornal Nós</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/contaorgNOSV.csv'
data = pd.read_csv(file_path, sep=';')

# Substituição
replace_names = {
    "Accenture": "Accenture",
    "Fundação para a Ciência e Tecnologia": "FCT",
    "Fundação para a Ciência": "FCT",
    "Instituto de Letras e Ciências Humanas": "ILCH",
    "ePsi": "EPsi",
    "Escola de Psicologia": "EPsi",
    "Escola de Psicologia de o UMinho": "EPsi",
    "Escola de psicologia": "EPsi",
    "Centro de Estudos Galegos": "CEG",
    "UMinho?": "UMinho",
    "UMinho*": "UMinho"
}

exclude_names = ["25 de abril", "Ciências de o Comunicação", "Relações Internacionais"]

data['ORG'] = data['ORG'].replace(replace_names)
data = data[~data['ORG'].isin(exclude_names)]


# Soma das ocorrências dos nomes iguais
grouped_data = data.groupby('ORG')['Oco'].sum().reset_index()

top_n = 15
grouped_data = grouped_data.sort_values(by='Oco', ascending=False).head(top_n)

# Criação do Gráfico
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['ORG'], grouped_data['Oco'], color='skyblue')
plt.xlabel('Organização')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n} Ocorrências de Organizações no Jornal Nós')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Aplicámos o mesmo código utilizado anteriormente, com o novo <i>dataset</i>. Os números não estão a aparecer como inteiros, no entanto, não conseguimos fazer o <i>debug</i> do problema, admitimos que talvez esteja relacionado com os problemas de separação das colunas do <i>dataset</i> que encontrámos na exportação e importação destes <i>datasets</i>.</p>
# <p align="justify">A nível de resultados temos um número extremamente baixo, quando comparado com o gráfico anterior.</p>
# <p align="justify">Neste <i>dataset</i> EPsi (Escola de Psicologia) foi a organização com um maior número de ocorrências. Em segundo lugar está o CVR (Centro para a Valorização de Resíduos da Universidade do Minho) com cerca de 11 resultados, seguido da FCT (Fundação para a Ciência e Tecnologia)  com cerca de 10 resultados, a <i>Google</i> com cerca de 9 resultados e a Universidade do Minho com cerca de 8 resultados. Neste <i>dataset</i> há uma maior representação das escolas e institutos da Universidade do Minho, visto que também são referidos o Instituto de Ciências Sociais (ICS), a Escola de Engenharia,  o Instituto de Educação (IEP) e o Instituto de Letras e Ciências Humanas (ILCH), o que provavelmente deve acontecer porque o Jornal Nós realiza mais artigos sobre as escolas e institutos da UMinho, ou foca-se nessas mesmas organizações.</p>

# %% [markdown]
# ##### Comparação das Organizações - <b>Jornal Nós e CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Graphic 1 - Jornal Nós
file_path_nosv = '/content/contaorgNOSV.csv'
data_nosv = pd.read_csv(file_path_nosv, sep=';')

# Substituição
replace_names_nosv = {
    "Accenture": "Accenture",
    "Fundação para a Ciência e Tecnologia": "FCT",
    "Fundação para a Ciência": "FCT",
    "Instituto de Letras e Ciências Humanas": "ILCH",
    "ePsi": "EPsi",
    "Escola de Psicologia": "EPsi",
    "Escola de Psicologia de o UMinho": "EPsi",
    "Escola de psicologia": "EPsi",
    "Centro de Estudos Galegos": "CEG",
    "UMinho?": "UMinho",
    "UMinho*": "UMinho"
}

exclude_names_nosv = ["25 de abril", "Ciências de o Comunicação", "Relações Internacionais"]

data_nosv['ORG'] = data_nosv['ORG'].replace(replace_names_nosv)
data_nosv = data_nosv[~data_nosv['ORG'].isin(exclude_names_nosv)]

# Soma das ocorrências dos nomes iguais
grouped_data_nosv = data_nosv.groupby('ORG')['Oco'].sum().reset_index()

top_n = 15
grouped_data_nosv = grouped_data_nosv.sort_values(by='Oco', ascending=False).head(top_n)

# Graphic 2 - CorpusR
file_path_corpusr = '/content/contaorgCORPUSRV.csv'
data_corpusr = pd.read_csv(file_path_corpusr, sep=';')

# Substituição
replace_names_corpusr = {
    "Fundação para Ciência e Tecnologia": "FCT",
    "Universidade?": "UMinho",
    "Academia?": "UMinho",
    "Universidade de o Minho": "UMinho",
    "Uminho-": "UMinho",
    "Academia": "UMinho",
    "Academia Minhota": "UMinho",
    "European University Sports Associety": "EUSA",
    "Gabinete de Sistemas de Informação": "GSI",
    "Gabinete de Sistemas de Informação de o Universidade de o Minho": "GSI",
    "Gabinete de Sistemas de Informação de o UMinho": "GSI",
    "Serviços de Ação Social": "SASUM",
    "SAS": "SASUM",
    "Serviços de Acção Social": "SASUM",
    "Serviços de Acção Social?": "SASUM",
    "Serviços de Acção Social de o UM": "SASUM",
    "Serviços de Ação Social de o Academia Minhota": "SASUM",
    "Serviços de Ação Social de o Universidade de o Minho": "SASUM",
    "Serviços de Acção Social de o Universidade de o Minho": "SASUM",
    "Bomboémia?": "Bomboémia",
    "Conselho Cultural de o Universidade de o Minho": "Conselho Cultural",
    "Conselho Cultural de o UMinho": "Conselho Cultural",
    "Conselho Cultural?": "Conselho Cultural",
    "conselho Cultural": "Conselho Cultural",
    "Rádio Universitária": "RUM",
    "Rádio Universitária de o Minho": "RUM",
    "Tuna Universitária de o Minho": "TUM",
    "Departamento Administrativo e Financeiro": "DAF",
    "Departamento Administrativo e financeiro de o SASUM": "DAF",
    "Conselho Geral": "CG",
    "Conselho Geral de o Universidade": "CG",
    "conselho geral": "CG",
    "Conselho Geral de o UM": "CG",
    "Conselho Geral?": "CG",
    "o Conselho Geral": "CG",
    "Departamento Alimentar de o Serviços de Acção Social de o Universidade de o Minho": "Departamento Alimentar",
    "departamento Alimentar": "Departamento Alimentar",
    "Departamento Alimentar de o Serviços de Acção Social de o UMinho": "Departamento Alimentar",
    "Conselho Fiscal e Jurisdicional de o AAUMinho": "CFJ",
    "Conselho Fiscal e Jurisdicional": "CFJ",
    "Associação Académica da Universidade do Minho": "AAUM",
    "Associação académica de o Universidade de o Minho": "AAUM",
    "Associação Académica de o Universidade de o Minho": "AAUM",
    "associação Académica": "AAUM",
    "associação académica de o Universidade de o Minho": "AAUM",
    "Associação Académica?": "AAUM",
    "Associação Académica": "AAUM",
    "associação académica de o UMinho": "AAUM",
    "Associação Académica de o UMinho": "AAUM",
    "UMinho?" : "UMinho"
}

exclude_names_corpusr = ["serviço", "Licenciatura", "Tuna", "Departamento"]

data_corpusr['ORG'] = data_corpusr['ORG'].replace(replace_names_corpusr)
data_corpusr = data_corpusr[~data_corpusr['ORG'].isin(exclude_names_corpusr)]

# Soma das ocorrências dos nomes iguais
grouped_data_corpusr = data_corpusr.groupby('ORG')['Oco'].sum().reset_index()

grouped_data_corpusr = grouped_data_corpusr.sort_values(by='Oco', ascending=False).head(top_n)

# Criação dos Gráficos lado a lado
fig, axs = plt.subplots(1, 2, figsize=(20, 8))

# Gráfico Jornal Nós
axs[0].bar(grouped_data_nosv['ORG'], grouped_data_nosv['Oco'], color='skyblue')
axs[0].set_xlabel('Organização')
axs[0].set_ylabel('Número de Ocorrências')
axs[0].set_title(f'Top {top_n} Ocorrências de Organizações no Jornal Nós')
axs[0].set_xticklabels(grouped_data_nosv['ORG'], rotation=90)

# Gráfico CorpusR
axs[1].bar(grouped_data_corpusr['ORG'], grouped_data_corpusr['Oco'], color='darkblue')
axs[1].set_xlabel('Organização')
axs[1].set_ylabel('Número de Ocorrências')
axs[1].set_title(f'Top {top_n} Ocorrências de Organizações no CorpusR')
axs[1].set_xticklabels(grouped_data_corpusr['ORG'], rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-9cfcaa5144a5>:110: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(grouped_data_nosv['ORG'], rotation=90)
# <ipython-input-37-9cfcaa5144a5>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(grouped_data_corpusr['ORG'], rotation=90)

# %% [markdown]
# <p align="justify">Existe uma diferença acentuada entre o número de ocorrências nos gráficos, sendo necessário salientar que no segundo gráfico o resultado com maior número de ocorrências possui mais de 800 ocorrências, enquanto que no primeiro apenas 18. Existe uma diferença de escala muito elevada.</p>
# <p align="justify">Porém, é interessante notar que no primeiro gráfico existe um foco nas escolas e instituições da Universidade do Minho, enquanto que no segundo os resultados são predominantemente de organizações de serviços administrativos e sociais e organizações socioculturais.</p>

# %% [markdown]
# ### Extração de Verbos

# %% [markdown]
# <p align="justify">Após a extração de Entidades Nomeadas decidimos realizar uma extração de verbos. Dado que se tratam também de variáveis qualitativas, decidimos continuar a utilizar o gráfico de barras, visto que o considerámos a melhor forma de visualização dos resultados.</p>
# <p align="justify">Tivemos que converter os ficheiros para o formato CSV UTF-8 no <i>Excel</i>, no entanto, neste caso não tivemos que reorganizar colunas.</p>
# <p align="justify">Uma vez que associámos as cores azul escuro e azul claro aos gráficos das Entidades Nomeadas, decidimos utilizar o verde escuro e o verde claro para os verbos.</p>

# %% [markdown]
# ##### Importação dos Verbos - <b>CorpusR</b>

# %%
import pandas as pd


file_path = '/content/verbosCORPUSR.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#          VERBOS;Oco
# 0          ter;7840
# 1        fazer;3717
# 2        poder;2544
# 3        haver;2326
# 4          ser;1377
# 5        estar;1345
# 6          dar;1265
# 7        dizer;1257
# 8       querer;1196
# 9    trabalhar;1083
# 10          vir;978
# 11        saber;968
# 12       passar;882
# 13        dever;878
# 14    conseguir;876
# 15          ver;775
# 16           ir;750
# 17    continuar;684
# 18        criar;670
# 19      existir;667
# 20  desenvolver;663
# 21        achar;657
# 22       gostar;649
# 23        ficar;644
# 24       pensar;625
# 25      começar;564
# 26     conhecer;563
# 27       deixar;544
# 28     permitir;519
# 29     realizar;510

# %% [markdown]
# <p align="justify">Fizemos a importação dos primeiros 30 resultados, no entanto, notámos que alguns dos verbos que ocorrem mais neste <i>dataset</i> são frequentemente usados na língua portuguesa por serem verbos auxíliares (ter, haver), verbos de estado (ser, estar), verbos de deslocação (ir, vir). Assim, decidimos colocar estes verbos numa lista de exclusão:</p>
# - ter</p>
# - dizer</p>
# - fazer </p>
# - haver</p>
# - ir </p>
# - dar </p>
# - ser</p>
# - vir</p>
# - estar</p>

# %% [markdown]
# ###### Visualização dos Verbos - <b>CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = '/content/verbosCORPUSR.csv'
data = pd.read_csv(file_path, sep=';')

# Verbos a excluir
exclude_verbs = ["ter", "dizer", "fazer", "haver", "ir", "dar", "ser", "vir", "estar"]

# Exclui os verbos
filtered_verbs = data[~data['VERBOS'].isin(exclude_verbs)]

grouped_verbs = filtered_verbs.groupby('VERBOS')['Oco'].sum().reset_index()

top_n_verbs = 20
grouped_verbs = grouped_verbs.sort_values(by='Oco', ascending=False).head(top_n_verbs)

# Criação do Gráfico para VERBOS
plt.figure(figsize=(10, 6))
plt.bar(grouped_verbs['VERBOS'], grouped_verbs['Oco'], color='darkgreen')
plt.xlabel('Verbo')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n_verbs} Ocorrências de Verbos no CorpusR')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Para fazermos uma melhor análise dos verbos mais utilizados, decidimos visualizar no gráfico os primeiros 20 resultados, em vez de 15.</p>
# <p align="justify">Utilizámos os códigos anteriores como base para este código. Alterámos o <i>dataset</i> a ser carregado, mudámos as palavras a serem excluídas, substituímos 'ORG' por 'VERBOS' no código e removemos a parte do código que renomeava alguns resultados dos códigos anteriores, visto que neste código não tivemos essa necessidade.</p>
# <p align="justify">O verbo que se destaca neste <i>dataset</i> é o verbo "poder" com mais de 2500 ocorrências. O segundo lugar, com menos de metade das ocorrências, é do verbo "querer" (com mais de 1000 ocorrências) e o terceiro do verbo "trabalhar" com um número semelhante. São seguindos pelos verbos "saber", "passar", "dever", "conseguir", "ver", "continuar", "criar", "existir", "desenvolver", "achar", "gostar" "ficar" e "pensar" que possuem um número semelhante de ocorrências (ligeiramente maior do que 500). </p>
# <p align="justify">Existe uma predominância de verbos relacionados com ações "trabalhar", "criar" e "desenvolver", verbos relacionados com processos cognitivos "pensar", "saber" e "conhecer" e ainda verbos associados ao mundo académico como "passar", "conseguir" e "desenvolver".</p>

# %% [markdown]
# ##### Importação dos Verbos - <b>Jornal Nós</b>

# %%
import pandas as pd


file_path = '/content/verbosNOS.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#         VERBOS;Oco
# 0          ter;319
# 1        haver;161
# 2        fazer;158
# 3        poder;124
# 4     trabalhar;85
# 5           vir;70
# 6           dar;58
# 7           ser;56
# 8      permitir;51
# 9           ver;51
# 10       passar;50
# 11     conhecer;49
# 12        estar;48
# 13        dizer;46
# 14        dever;46
# 15      começar;45
# 16       gostar;42
# 17  desenvolver;42
# 18       querer;41
# 19        criar;40
# 20       pensar;39
# 21        saber;39
# 22       acabar;38
# 23       chegar;37
# 24           ir;37
# 25    continuar;37
# 26        viver;37
# 27        levar;31
# 28      estudar;31
# 29       deixar;31

# %% [markdown]
# <p align="justify">Fizemos a importação dos primeiros 30 resultados e decidimos utilizar a mesma lista de exclusões utilizada na análise anterior.</p>

# %% [markdown]
# ###### Visualização dos Verbos - <b>Jornal Nós</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = '/content/verbosNOS.csv'
data = pd.read_csv(file_path, sep=';')

# Verbos a excluir
exclude_verbs = ["ter", "dizer", "fazer", "haver", "ir", "dar", "ser", "vir", "estar"]

# Exclui os verbos
filtered_verbs = data[~data['VERBOS'].isin(exclude_verbs)]

grouped_verbs = filtered_verbs.groupby('VERBOS')['Oco'].sum().reset_index()

top_n_verbs = 20
grouped_verbs = grouped_verbs.sort_values(by='Oco', ascending=False).head(top_n_verbs)

# Criação do Gráfico para VERBOS
plt.figure(figsize=(10, 6))
plt.bar(grouped_verbs['VERBOS'], grouped_verbs['Oco'], color='yellowgreen')
plt.xlabel('Verbo')
plt.ylabel('Número de Ocorrências')
plt.title(f'Top {top_n_verbs} Ocorrências de Verbos no Jornal Nós')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p align="justify">Utilizámos o código anterior (apenas com um <i>dataset</i> diferente) para visualizar os nossos dados. Consultamos ainda a lista de cores disponível na documentação do <i>Matplotlib</i> para escolher as novas cores do nosso gráfico.</p>
# <p align="justify">O verbo que ocorre com maior frequência é o verbo "poder" com cerca de 125 ocorrências, seguido do verbo "trabalhar" com mais de 80 ocorrências e os verbos "permitir" e "ver" com cerca de 50 ocorrências. Depois destes resultados, só existe uma ligeira variação númerica, tendo os restantes verbos entre 30 a 50 ocorrências.</p>

# %% [markdown]
# ##### Comparação dos Verbos - <b>Jornal Nós e CorpusR</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Jornal Nós - Verbos
file_path_nos = '/content/verbosNOS.csv'
data_nos = pd.read_csv(file_path_nos, sep=';')

# Verbos a excluir
exclude_verbs_nos = ["ter", "dizer", "fazer", "haver", "ir", "dar", "ser", "vir", "estar"]

# Exclui os verbos
filtered_verbs_nos = data_nos[~data_nos['VERBOS'].isin(exclude_verbs_nos)]

grouped_verbs_nos = filtered_verbs_nos.groupby('VERBOS')['Oco'].sum().reset_index()

top_n_verbs = 20
grouped_verbs_nos = grouped_verbs_nos.sort_values(by='Oco', ascending=False).head(top_n_verbs)

# CorpusR - Verbos
file_path_corpusr = '/content/verbosCORPUSR.csv'
data_corpusr = pd.read_csv(file_path_corpusr, sep=';')

# Verbos a excluir
exclude_verbs_corpusr = ["ter", "dizer", "fazer", "haver", "ir", "dar", "ser", "vir", "estar"]

# Exclui os verbos
filtered_verbs_corpusr = data_corpusr[~data_corpusr['VERBOS'].isin(exclude_verbs_corpusr)]

grouped_verbs_corpusr = filtered_verbs_corpusr.groupby('VERBOS')['Oco'].sum().reset_index()

grouped_verbs_corpusr = grouped_verbs_corpusr.sort_values(by='Oco', ascending=False).head(top_n_verbs)

# Criação dos Gráficos ao lado um do outro
fig, axs = plt.subplots(1, 2, figsize=(20, 8))

# Gráfico Nós - Verbos
axs[0].bar(grouped_verbs_nos['VERBOS'], grouped_verbs_nos['Oco'], color='yellowgreen')
axs[0].set_xlabel('Verbo')
axs[0].set_ylabel('Número de Ocorrências')
axs[0].set_title(f'Top {top_n_verbs} Ocorrências de Verbos no Jornal Nós')
axs[0].set_xticklabels(grouped_verbs_nos['VERBOS'], rotation=90)

# Gráfico CorpusR - Verbos
axs[1].bar(grouped_verbs_corpusr['VERBOS'], grouped_verbs_corpusr['Oco'], color='darkgreen')
axs[1].set_xlabel('Verbo')
axs[1].set_ylabel('Número de Ocorrências')
axs[1].set_title(f'Top {top_n_verbs} Ocorrências de Verbos no CorpusR')
axs[1].set_xticklabels(grouped_verbs_corpusr['VERBOS'], rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-4528c0608b55>:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(grouped_verbs_nos['VERBOS'], rotation=90)
# <ipython-input-35-4528c0608b55>:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(grouped_verbs_corpusr['VERBOS'], rotation=90)

# %% [markdown]
# <p align="justify">Aproveitámos os códigos anteriores para este gráfico.</p>
# <p align="justify">Curiosamente, o verbo com mais ocorrências nos dois <i>datasets</i> é o verbo "poder". Ambos destacam-se em relação ao seu segundo resultado, apesar de como já foi mencionado, o <i>corpus</i> do Jornal Nós é muito menor do que o <i>corpus</i> reduzido. </p>
# <p align="justify">Existem 10 verbos em comum em ambos os gráficos: "poder", "querer", "trabalhar", "saber", "ver", "passar", "conhecer", "dever", "continuar" e "criar".</p>

# %% [markdown]
# ### Dias com mais artigos - <b>Jornal NÓS</b>

# %% [markdown]
# <p align="justify">Considerámos que seria interessante verificar qual a quantidade de artigos publicados por data no Jornal Nós. Aproveitámos o código realizado na aula que extrai as datas, os títulos e o nome do ficheiro e fizemos alterações para que só imprimisse as datas.</p>
# <p align="justify">Dado que as datas são variáveis quantitativas contínuas (representam pontos no tempo que podem ser ordenados e medidos), considerámos que o gráfico de barra com linha seria o melhor para visualizar os nossos dados. Experimentámos ainda um gráfico de barras.</p>
# <p align="justify">De notar, que não temos as datas de todos os artigos, por isso o gráfico só tem as datas daqueles que as possuem nos metadados.</p>

# %% [markdown]
# #### Importação das datas

# %%
import pandas as pd


file_path = '/content/datasNOS.csv'

df = pd.read_csv(file_path, encoding='UTF-8')


print(df.head(30))
# Out:
#           DATA
# 0   17/06/2015
# 1          NaN
# 2   17/06/2015
# 3   17/06/2015
# 4   17/06/2015
# 5   17/06/2015
# 6   17/06/2015
# 7   09/07/2015
# 8   13/10/2015
# 9          NaN
# 10  13/10/2015
# 11  13/10/2015
# 12  13/10/2015
# 13  13/10/2015
# 14  13/10/2015
# 15  13/10/2015
# 16  30/11/2015
# 17  30/11/2015
# 18         NaN
# 19  30/11/2015
# 20  30/11/2015
# 21  30/11/2015
# 22  30/11/2015
# 23  19/12/2015
# 24  19/12/2015
# 25  19/12/2015
# 26         NaN
# 27  19/12/2015
# 28  19/12/2015
# 29  19/12/2015

# %% [markdown]
# ##### Visualização dos Dados

# %% [markdown]
# <b> Gráfico de Barras </b>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/datasNOS.csv'
df = pd.read_csv(file_path)

# Remover linhas com datas 'none'
df = df[df['DATA'] != 'none']

# Converter a coluna 'DATA' para datetime
df['DATA'] = pd.to_datetime(df['DATA'], format='%d/%m/%Y')

# Extrai o mês e o ano de cada data
df['Year_Month'] = df['DATA'].dt.to_period('M')

# Conta o número de artigos por mês e ano
article_counts = df['Year_Month'].value_counts().sort_index()

# Gráfico
plt.figure(figsize=(12, 6))
article_counts.plot(kind='bar', color='orange')
plt.xlabel('Mês e Ano')
plt.ylabel('Quantidade de Artigos')
plt.title('Quantidade de Artigos por Mês e Ano')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# <p align="justify">Este código lê o <i>dataset</i>, remove as ocorrências de artigos sem data (identificados por <i>none</i>), converte a coluna "DATA" para <i>datetime</i> (um módulo do <i>Python</i> para manipular datas) em que o formato corresponde a dd/mm/aaaa. De seguida, extrai o mês e o ano (Existem muitas datas pelo que considerámos mais proveitoso realizar uma análise de artigos por mês e ano e não por dia, mês e ano.) e conta as suas ocorrências. No final cria o gráfico.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar o arquivo CSV
file_path = '/content/datasNOS.csv'
df = pd.read_csv(file_path)


df = df[df['DATA'] != 'none']

# Converte a coluna 'DATA' para datetime
df['DATA'] = pd.to_datetime(df['DATA'], format='%d/%m/%Y')

# Extrai o mês e o ano de cada data
df['Year_Month'] = df['DATA'].dt.to_period('M')

# Conta o número de artigos por mês e ano
article_counts = df['Year_Month'].value_counts().sort_index()

# Gráfico
plt.figure(figsize=(12, 6))

# Gráfico de linha
plt.plot(article_counts.index.astype(str), article_counts.values, marker='o', color='blue', linestyle='-', label='Linha')

# Gráfico de barras
article_counts.plot(kind='bar', color='orange', alpha=0.7, label='Barras')

plt.xlabel('Mês e Ano')
plt.ylabel('Quantidade de Artigos')
plt.title('Quantidade de Artigos por Mês e Ano')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# <p align="justify">O código é semelhante, com a exceção da rotação das datas para uma leitura mais clara e a adição da linha de código seguinte que cria o gráfico de linhas:</p>
# plt.plot(article_counts.index.astype(str), article_counts.values, marker='o', color='blue', linestyle='-', label='Linha')
# <p align="justify">O mês com mais publicações é o mês de maio de 2017 com 8 publicações. O segundo número mais alto de publicações é de 7 que ocorreram nos meses de outubro de 2015, fevereiro de 2016, abril de 2016, outubro de 2016, janeiro de 2017, abril de 2017, outubro de 2017, fevereiro de 2018, novembro de 2020 e setembro de 2023.</p>
# <p align="justify">Entre dezembro de 2018 e outubro de 2020 não existem publicações e até abril de 2022 existe uma quebra a nível do número de publicações que só recupera a partir de abril de 2023, talvez devido ao retomar do ritmo de uma possível quebra com a pandemia. Porém, deve-se salientar que o mesmo acontece entre maio de 2017 e outubro de 2017 e ainda entre junho de 2015 e outubro de 2015, no entanto não são tão acentuadas.</p>

# %% [markdown]
# ### Análise de Sentimento <i>Harry Potter</i>

# %% [markdown]
# <p align="justify">No código que foi possível observar no Caderno de Campo, foram acrescentadas umas linhas que criassem um <i>dataframe</i> que fosse exportado para <i>Excel</i> onde estivesse por linha o número do capítulo, o número total de palavras positivas, negativas e o número de palavras totais por capítulo.</p>

# %%
import re
import pandas as pd


def le_livro(nome_livro):
    with open (nome_livro, encoding="utf-8") as arquivo_livro:
        livro=arquivo_livro.read()#Carrega o conteúdo completo do livro para a variável livro
    return livro.split('#')#Quebra o conteúdo o livro por "#", utilizado para sinalizar um novo capítulo

def analisa_capitulos(capitulos):

    dicionario=carrega_lexico()
    dados = [] # os dados ficam neste dicionário

    for n,capitulo in enumerate(capitulos):
        positivas=0
        negativas=0

        print("-"*50)
        for word in dicionario:
            quantidade=len(re.findall(word,capitulo))
            if dicionario[word]>0:
                positivas+=quantidade
            else:
                negativas+=quantidade

        total_palavras = len(capitulo.split()) #len de cada capítulo
        dados.append([n, positivas, negativas, total_palavras]) #junta os dados no dicionário

        df = pd.DataFrame(dados, columns=['Capitulo', 'Positivas', 'Negativas', 'Total de Palavras']) #cria um df
        df.to_excel('sentimento_capitulos.xlsx', index=False)  # envia os dados para o Excel o index=False para não enumerar a partir do 0


        print(f"Capitulo {n}: Positivas: {positivas} - Negativas: {negativas}")
            #print(f"{word} ({dicionario[word]}): {quantidade}")



def carrega_lexico():
    with open("positivos.txt", encoding="utf-8") as learquivo:
        positivos=learquivo.read().splitlines()
    with open("negativos.txt", encoding="utf-8") as learquivo:
        negativos=learquivo.read().splitlines()

    dicionario_lexico={x:1 for x in positivos} | {x:-1 for x in negativos}#Forma um dicionario lexico com as palavras dos arquivos positivos e negativos

    return(dicionario_lexico)

#HP_ler = le_livro("HP.txt")
#analisa_capitulos(HP_ler)

#capitulos=le_livro("HP.txt")
#print(len(capitulos))
#analisa_capitulos(capitulos)

def anota (m):
    palavra = m.group(0)
    if palavra in dicionario:
        return f'<span style="color:{"green" if dicionario[palavra] == 1 else "red"}">{palavra}</span>'
    else:
        return palavra

def anotaTexto(texto, output_file):
    with open(output_file, 'w', encoding='utf-8') as f_out:
        anotado = re.sub(r'\b\w+\b', anota, texto)  # \b é um word boundary
        f_out.write(anotado)

        count_1 = anotado.count('<span style="color:green">')
        count_minus_1 = anotado.count('<span style="color:red">')


        counts_html = f"<p>Count (1): <span style='color:green'>{count_1}</span></p>\n"
        counts_html += f"<p>Count (-1): <span style='color:red'>{count_minus_1}</span></p>\n"
        f_out.write(counts_html)

def le_livro(nome_livro):
    with open(nome_livro, encoding="utf-8") as arquivo_livro:
        livro = arquivo_livro.read()
    return livro

def analisa_e_anota(nome_livro, output_file):
    livro = le_livro(nome_livro)
    anotaTexto(livro, output_file)

dicionario = carrega_lexico()
nome_livro = "HP.txt"
output_file = "HP_cores.html"
analisa_e_anota(nome_livro, output_file)

# %% [markdown]
# <p align="justify"> No <i>Excel</i>, foi acrescentada uma nova coluna para fazer o acerto entre palavras negativas e positivas. A necessidade de acertar os números deveu-se ao facto de que no ficheiro "positivos.txt" existirem 20677 entradas, enquanto que no "negativos.txt" 53669 entradas. Ao dividir 20677 por 53669 obtivemos o valor 0.385 e realizámos um acerto através desse valor.</p>
#
# <p align="justify">No entanto, os valores eram todos positivos, o que trouxe a necessidade de realizar um acerto que espelhasse melhor a realidade. Calculou-se o número total de palavras positivas e negativas e ao dividir um pelo o outro obtivemos o valor "0,530535" que foi usado para realizar o acerto. O valor final da análise de sentimento calculou-se através da subtração do valor positivo ao valor negativo ajustado.</p>
#
# <p align="justify">De seguida, criámos a variável "Análise_Sent_Cm2" através da divisão do valor da análise de sentimento pelo número total de palavras e a variável "Analise_Sent_Pals_Mil" ao multiplicar esse valor por 1000.</p>
#
# | Capitulo | Positivas | Negativas | Total de Palavras | Negativas Ajustadas | Análise de Sentimento | Análise_Sent_Cm2 | Analise_Sent_Pals_Mil |
# |----------|-----------|-----------|-------------------|---------------------|------------------------|------------------|-----------------------|
# | 0        | 10        | 28        | 225               | 10.78               | -0.78                  | -0.003466667     | -3.47                 |
# | 1        | 228       | 424       | 4879              | 224.9468101         | 3.053189877            | 0.000625782      | 0.63                   |
# | 2        | 176       | 299       | 3699              | 158.6299439         | 17.37005607            | 0.004695879      | 4.70                   |
# | 3        | 152       | 366       | 4246              | 194.1757842         | -42.17578421           | -0.009933063     | -9.93                 |
# | 4        | 163       | 304       | 3914              | 161.2826186         | 1.717381421            | 0.000438779      | 0.44                   |
# | 5        | 278       | 508       | 7257              | 269.5117442         | 8.488255796            | 0.001169665      | 1.17                   |
# | 6        | 252       | 493       | 6890              | 261.5537203         | -9.553720261           | -0.001386607     | -1.39                 |
# | 7        | 234       | 356       | 4702              | 188.8704349         | 45.12956509            | 0.009597951      | 9.60                   |
# | 8        | 139       | 294       | 3306              | 155.9772693         | -16.97726928           | -0.00513529      | -5.14                 |
# | 9        | 196       | 461       | 5497              | 244.5766025         | -48.57660252           | -0.00883693      | -8.84                 |
# | 10       | 200       | 373       | 4780              | 197.8895287         | 2.110471284            | 0.000441521      | 0.44                   |
# | 11       | 157       | 262       | 3714              | 139.0001515         | 17.99984846            | 0.004846486      | 4.85                   |
# | 12       | 240       | 413       | 5859              | 219.1109259         | 20.8890741             | 0.003565297      | 3.57                   |
# | 13       | 143       | 241       | 3497              | 127.858918          | 15.14108198            | 0.004329735      | 4.33                   |
# | 14       | 135       | 251       | 3795              | 133.1642673         | 1.835732687            | 0.000483724      | 0.48                   |
# | 15       | 211       | 536       | 5472              | 284.3667222         | -73.36672223           | -0.013407661     | -13.41                |
# | 16       | 294       | 564       | 6989              | 299.2217003         | -5.221700258           | -0.000747131     | -0.75                 |
# | 17       | 303       | 454       | 5869              | 240.862858          | 62.13714199            | 0.010587347      | 10.59                  |
#
#
# <p align="justify"> O gráfico que resultou da Análise de Sentimento foi o seguinte:</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">O valor "1" equivale ao cabeçalho e ao prólogo, pelo que começámos a nossa análise a partir do valor "2". Podemos observar de uma maneira geral que parecem existir mais capítulos positivos (10), do que capítulos negativos (5), no entanto, quando um capítulo é negativo este parece ter uma maior concentração de valor negativo, do que quando é positivo onde os valores têm uma tendência para serem mais baixos e estarem mais próximos de um valor neutro.</p>
# <p align="justify">A história começa com um tom levemente positivo e antes do capítulo final (que é o mais positivo de todo o livro), há um capítulo com uma maior concentração de sentimento negativo, o que indica a possibilidade de indício de algum confronto final.</p>
# <p align="justify">No meio da história, no valor "8", correspondente ao capítulo 7, é onde encontramos o segundo capítulo com um valor positivo que é seguido por dois capítulos onde o sentimento negativo vai tendo um aumento crescente, para no capítulo a seguir retomar um sentimento positivo, quase neutro que cresce ligeiramente até voltar a descer e entrar no capítulo com a maior concentração de sentimento negativo.</p>

# %% [markdown]
# ## Conclusão

# %% [markdown]
# <p align="justify">O trabalho realizado nesta UC fez-nos adquirir novas competências e também desenvolver conhecimentos já adquiridos no primeiro semestre na cadeira de Processamento de linguagem natural.</p>
# <p align="justify">Conseguimos compreender como se faz <i>web scraping</i>, como analisar códigos HTML de forma a conseguirmos extrair as TAGS desejadas e "guardar" ou excluir as que não queremos manter no documento e a limpar ficheiros para que os possamos analisar.</p>
# <p align="justify">A tarefa de limpeza de um <i>corpus</i> antes de o analisar é talvez a mais demorada e também árdua, uma vez que aparecem erros que não conseguimos realizar o <i>debug</i> ou por mais que o código esteja "correto" este não realiza a ação que nos é desejada, tal como aconteceu na limpeza do <i>corpus</i> do jornal Nós, onde demoramos quase um mês a conseguir colocar o cardinal "#" antes do título do artigo de modo a conseguirmos formar um ficheiro <i>Markdown</i> válido.</p>
# <p align="justify">Um dos novos conhecimentos que adquirimos e que consideramos que foi muito benéfico, foi a criação de ficheiros "Makefile". A automatização permite-nos poupar tempo ao escrever os códigos e também atualizar os ficheiros rapidamente em caso de ter sido feita alguma alteração.</p>
# <p align="justify">A nível da análise de sentimento, consideramos que criar o nosso próprio léxico, foi uma excelente forma de aprendermos como funcionam outras ferramentas tais como a <i>Linguakit</i>, no entanto,  o nosso léxico necessita de vários acertos de forma a não apanhar falsos positivos e talvez fosse importante acrescentar aos nossos ficheiros palavras relacionadas com o universo de "Harry Potter" que não são utilizadas no nosso dia a dia tais como os insultos "muggle" e "sangue de lama". Sugerimos assim para uma ideia futura, a criação de um "SentilexHP", onde pudessem ser incluídos termos que só existem nesse universo.</p>
# <p align="justify">Um dos maiores desafios que tivemos neste trabalho foi na secção da visualização e criação dos gráficos. Alguns dos ficheiros csv que criamos como <i>datasets</i> estavam a ter problemas de <i>encoding</i> o que fazia com que as colunas não estivessem a conseguir ser lidas e os caracteres especiais davam azo a novos erros. Para além disso, sentimos alguma dificuldade em fazer análises de um corpus tão extenso, uma vez que verificar a informação manualmente torna-se uma tarefa muito mais extenuante e quase impossível. A automatização fornece uma grande ajuda, no entanto também pode criar erros que não conseguimos fazer o <i>debug</i>, devido à grande quantidade de informação. </p>
# <p align="justify">A limpeza de um <i>dataset</i> é também um trabalho árduo e são precisas muitas horas de trabalho e dedicação. Nos <i>datasets</i> que utilizámos neste presente trabalho apenas fizemos uma semi-limpeza onde realizámos um pouco de trabalho de organização, categorização e limpeza de falsos-positivos. No entanto, para melhorar os resultados e conclusões que retirámos destes exercícios sugeríamos uma análise, organização e categorização total de todos os <i>datasets</i> para ter resultados o mais corretos possíveis. Houve também entidades que não foram corretamente etiquetadas e isso pode alterar alguns dos números de ocorrências e seleção dos termos.</i>

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# Bhattacharyea, A. (2023, July 11). <i>Creating a python makefile.</i> Earthly Blog. https://earthly.dev/blog/python-makefile/
#
# <i>beautifulsoup4.</i> (2024, 17 de Janeiro). PyPI. https://pypi.org/project/beautifulsoup4/
#
# <i>ComUM.</i> (s.d.). ComUM. https://www.comumonline.com/
#
# <i>csv — CSV File Reading and Writing.</i> (s.d.). Python Documentation. https://docs.python.org/3/library/csv.html
#
# Cura, H. (2020, 11 de Dezembro). Web Scraping - Saiba o que é e para que serve. Pplware. https://pplware.sapo.pt/internet/web-scraping-saiba-o-que-e-e-para-que-serve/
#
# <i>datetime — Basic date and time types.</i> (s.d.). Python Documentation. https://docs.python.org/3/library/datetime.html
#
# GeeksforGeeks. (2024, 27 de Março). <i>Python Collections Module.</i> GeeksforGeeks. https://www.geeksforgeeks.org/python-collections-module/
#
# <i>glob — Unix style pathname pattern expansion.</i> (s.d.). Python Documentation. https://docs.python.org/3/library/glob.html
#
# <i>jjcli.</i> (2024, 6 de Junho). PyPI. https://pypi.org/project/jjcli/
#
# <i>Jornal Online UMINHO.</i> Jornal Nos. (s.d.). http://www.nos.uminho.pt/
#
# <i>List of named colors — Matplotlib 3.9.0 documentation. (s.d.).</i> https://matplotlib.org/stable/gallery/color/named_colors.html
#
# <i>Matplotlib Subplot.</i> (s.d.). W3Schools. https://www.w3schools.com/python/matplotlib_subplot.asp
#
# <i>pandas.DataFrame.isin — pandas 2.2.2 documentation.</i> (s.d.). https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html
#
# <i>Portuguese · SPACY Models Documentation.</i> (s.d.). Portuguese. https://spacy.io/models/pt
#
# <i>re — Regular expression operations.</i> (s.d.). Python Documentation. https://docs.python.org/3/library/re.html
#
# SIMÕES, A. M., & ALMEIDA, J. J. (2003). Histórias de vida + processamento estrutural = museu da pessoa. In RAMALHO, J. C. et al. (Eds.), <i>XATA 2003: XML: aplicações e tecnologias associadas: actas, 1.</i> Braga. https://repositorium.sdum.uminho.pt/handle/1822/629
#
# <i>The official YAML web site.</i> (s.d.). https://yaml.org/
#
# <i>UMdicas.</i> (s.d.). UMdicas. https://www.dicas.sas.uminho.pt/
#
# <i>User Guide — pandas 2.2.2 documentation. (s.d.). https://pandas.pydata.org/docs/user_guide/index.html</i>
#
# <i>Using Matplotlib — Matplotlib 3.9.0 documentation.</i> (s.d.). https://matplotlib.org/stable/users/index
#
# <i>WGET - GNU Project - Free Software Foundation.</i> (s.d.). https://www.gnu.org/software/wget/

# %% [markdown]
# ## <i>Github</i>

# %% [markdown]
# <p align="justify">Os documentos referidos neste relatório podem ser consultados em: </p>

# %% [markdown]
# [Ficheiros extraídos do Jornal Nós](https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/Nos)
#
# [Github do Grupo](https://github.com/alexandrafernandesHD/grupo1avd)
#
# [Github da Turma](https://github.com/alexandrafernandesHD/avd-MHD)
#
# [Pasta do Github - Entrevista Alexandra Fernandes](https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/EntrevistasAVD/AlexandraFernandes)
#
# [Pasta do Github - Entrevista Francisca Pimenta](https://github.com/alexandrafernandesHD/avd-MHD/tree/main/Arquivo_UMSombra/EntrevistasAVD/FranciscaPimenta)

# %% [markdown]
# ## Outros <i>links</i>

# %% [markdown]
# [Extrações iniciais do Jornal Nós](https://drive.google.com/drive/folders/1wMFEWdMwxv8tgrQ8VXqCBMVi1oaUGiFA)
